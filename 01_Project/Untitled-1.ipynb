# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import re
import spacy
from rank_bm25 import BM25Okapi

# %%
nlp = spacy.load("en_core_web_sm")

# %%
dataset = pd.read_json('train.json')

# %% [markdown]
# ## Text Preprocess

# %%
def preprocess(text):
    text = str(text)
    text = text.lower()
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub('\s+', ' ', text)
    text = text.strip()
    return text

# %% [markdown]
# ### Cut text to between 0 - 512 word because model cant read more than 512 words

# %%
def cut_text_to_512_words(text):
    doc = nlp(text)
    words = [token.text for token in doc]
    if len(words) > 256:
        cut_words = words[:450]
        cut_text = " ".join(cut_words)
        return cut_text
    else:
        return text

# %%
dataset['support'] = dataset['support'].apply(preprocess)
dataset['question'] = dataset['question'].apply(preprocess)

# %%
context = list(dataset['support'])

# %% [markdown]
# ### Rank BM25 for Passage ranking

# %%
tokenized_corpus = [doc.split(" ") for doc in context]
bm25 = BM25Okapi(tokenized_corpus)

# %% [markdown]
# ### TF-IDF for Passage ranking

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(context)

# %% [markdown]
# ### Function to find context based on question  return context1 : TF-IDF and context2 : RankBM25

# %%
def find_context(question):
    tokenized_question = question.split(" ")
    question_vector = vectorizer.transform([question])
    similiarity = cosine_similarity(question_vector, tfidf_matrix)
    n = 1
    top_indices = similiarity.argsort()[0][-n:][::-1]
    top_contexts = [context[idx] for idx in top_indices]
    
    context1 = cut_text_to_512_words(top_contexts[0])
    context2 = cut_text_to_512_words(bm25.get_top_n(tokenized_question, context, n=n)[0])
    
    return [context1,context2]

# %%
find_context('What is the short name of Oxygen')
# Out:
# ['all oxygen atoms have eight protons and most have eight neutrons as well what is the mass number of an oxygen isotope that has nine neutrons what is the name of this isotope',
#  'molecules with a carboxyl group are called carboxylic acids as with aldehydes the functional group in carboxylic acids is at the end of a carbon chain also as with aldehydes the c atom in the functional group is counted as one of the c atoms that defines the parent hydrocarbon name to name carboxylic acids the parent name of the hydrocarbon is used but the suffix oic acid is added']

# %%
import torch
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer

# %% [markdown]
# ## Bert question answering using pretrained

# %%
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
# Out:
# Downloading:   0%|          | 0.00/443 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]

# %%
### train ###

# %% [markdown]
# ## Extract answer from context function

# %%
def question_answer(question, text):
    answer = ''
    #tokenize question and text as a pair
    input_ids = tokenizer.encode(question, text)
    #string version of tokenized ids
    tokens = tokenizer.convert_ids_to_tokens(input_ids)
    
    #segment IDs
    #first occurence of [SEP] token
    sep_idx = input_ids.index(tokenizer.sep_token_id)
    #number of tokens in segment A (question)
    num_seg_a = sep_idx+1
    #number of tokens in segment B (text)
    num_seg_b = len(input_ids) - num_seg_a
    
    #list of 0s and 1s for segment embeddings
    segment_ids = [0]*num_seg_a + [1]*num_seg_b
    assert len(segment_ids) == len(input_ids)
    
    #model output using input_ids and segment_ids
    output = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]))
    
    #reconstructing the answer
    answer_start = torch.argmax(output.start_logits)
    answer_end = torch.argmax(output.end_logits)
    if answer_end >= answer_start:
        answer = tokens[answer_start]
        for i in range(answer_start+1, answer_end+1):
            if tokens[i][0:2] == "##":
                answer += tokens[i][2:]
            else:
                answer += " " + tokens[i]
              
    if answer.startswith("[CLS]"):
        answer = "Unable to find the answer to your question."
    print("Question : "+ question + "?")
    print("Predicted answer:\n{}".format(answer.capitalize()))
    return answer

# %%
answer_1 = question_answer('How many protons Oxygen have',(find_context('How many proton Oxygen have ?')))
# Out:
# Question : How many protons Oxygen have?
# Predicted answer:
# Protons

# %% [markdown]
# ### Evaluation just for test score you can delete all below

# %%
test_1 = []
test_2 = []
score_1 = 0
score_2 = 0

# %%
for index ,row in dataset.iterrows():
    print(index)
    context_lst = find_context(dataset['question'][index])
    answer_1 = question_answer(dataset['question'][index],context_lst[0])
    answer_2 = question_answer(dataset['question'][index],context_lst[1])
    if answer_1 == dataset['correct_answer'][index]:
        score_1 +=1
    elif dataset['correct_answer'][index] in answer_1:
        test_1.append([dataset['correct_answer'][index],answer_1])
    if answer_2 == dataset['correct_answer'][index]:
        score_2 +=1
    elif dataset['correct_answer'][index] in answer_2:
        test_2.append([dataset['correct_answer'][index],answer_2])
# Out:
# 0
# Question : what type of organism is commonly used in preparation of foods such as cheese and yogurt?
# Predicted answer:
# Bacteria
# Question : what type of organism is commonly used in preparation of foods such as cheese and yogurt?
# Predicted answer:
# Mesophilic
# 1
# Question : what phenomenon makes global winds blow northeast to southwest or the reverse in the northern hemisphere and northwest to southeast or the reverse in the southern hemisphere?
# Predicted answer:
# Coriolis
# Question : what phenomenon makes global winds blow northeast to southwest or the reverse in the northern hemisphere and northwest to southeast or the reverse in the southern hemisphere?
# Predicted answer:
# Coriolis
# 2
# Question : changes from a lessordered state to a moreordered state such as a liquid to a solid are always what?
# Predicted answer:
# Exothermic
# Question : changes from a lessordered state to a moreordered state such as a liquid to a solid are always what?
# Predicted answer:
# Exothermic
# 3
# Question : what is the least dangerous radioactive decay?
# Predicted answer:
# Alpha decay
# Question : what is the least dangerous radioactive decay?
# Predicted answer:
# Alpha decay
# 4
# Question : kilauea in hawaii is the worlds most continuously active volcano very active volcanoes characteristically eject redhot rocks and lava rather than this?
# Predicted answer:
# Smoke and ash
# Question : kilauea in hawaii is the worlds most continuously active volcano very active volcanoes characteristically eject redhot rocks and lava rather than this?
# Predicted answer:
# Smoke and ash
# 5
# Question : when a meteoroid reaches earth what is the remaining object called?
# Predicted answer:
# A meteorite
# Question : when a meteoroid reaches earth what is the remaining object called?
# Predicted answer:
# A meteorite
# 6
# Question : what kind of a reaction occurs when a substance reacts quickly with oxygen?
# Predicted answer:
# Combustion
# Question : what kind of a reaction occurs when a substance reacts quickly with oxygen?
# Predicted answer:
# Combustion
# 7
# Question : organisms categorized by what species descriptor demonstrate a version of allopatric speciation and have limited regions of overlap with one another but where they overlap they interbreed successfully?
# Predicted answer:
# Ring species ring species
# Question : organisms categorized by what species descriptor demonstrate a version of allopatric speciation and have limited regions of overlap with one another but where they overlap they interbreed successfully?
# Predicted answer:
# Ring species ring species
# 8
# Question : alpha emission is a type of what?
# Predicted answer:
# Radioactivity
# Question : alpha emission is a type of what?
# Predicted answer:
# Radioactivity
# 9
# Question : what is the stored food in a seed called?
# Predicted answer:
# Endosperm
# Question : what is the stored food in a seed called?
# Predicted answer:
# Endosperm
# 10
# Question : zinc is more easily oxidized than iron because zinc has a lower reduction potential since zinc has a lower reduction potential it is a more what?
# Predicted answer:
# Active metal
# Question : zinc is more easily oxidized than iron because zinc has a lower reduction potential since zinc has a lower reduction potential it is a more what?
# Predicted answer:
# Active metal
# 11
# Question : what is controlled by both genes and experiences in a given envionment?
# Predicted answer:
# Most animal behaviors
# Question : what is controlled by both genes and experiences in a given envionment?
# Predicted answer:
# Most animal behaviors
# 12
# Question : what tells you how much of the food you should eat to get the nutrients listed on the label?
# Predicted answer:
# The serving size
# Question : what tells you how much of the food you should eat to get the nutrients listed on the label?
# Predicted answer:
# The serving size
# 13
# Question : what are used to write nuclear equations for radioactive decay?
# Predicted answer:
# Nuclear symbols
# Question : what are used to write nuclear equations for radioactive decay?
# Predicted answer:
# Nuclear symbols
# 14
# Question : what is controlled by regulatory proteins that bind to regulatory elements on dna?
# Predicted answer:
# Transcription
# Question : what is controlled by regulatory proteins that bind to regulatory elements on dna?
# Predicted answer:
# Gene transcription
# 15
# Question : boron only occurs naturally in compounds with what element?
# Predicted answer:
# Oxygen
# Question : boron only occurs naturally in compounds with what element?
# Predicted answer:
# Oxygen
# 16
# Question : what organ systems link exchange surfaces with cells throughout the body?
# Predicted answer:
# 421 circulatory systems
# Question : what organ systems link exchange surfaces with cells throughout the body?
# Predicted answer:
# 421 circulatory systems
# 17
# Question : what occurs when the immune system attacks a harmless substance that enters the body from the outside?
# Predicted answer:
# Allergies
# Question : what occurs when the immune system attacks a harmless substance that enters the body from the outside?
# Predicted answer:
# An allergy
# 18
# Question : fertilization is the union of a sperm and egg resulting in the formation of what?
# Predicted answer:
# A zygote
# Question : fertilization is the union of a sperm and egg resulting in the formation of what?
# Predicted answer:
# A zygote
# 19
# Question : the plants alternation between haploid and diploud generations allow it to do what?
# Predicted answer:
# Alternates from generation to generation
# Question : the plants alternation between haploid and diploud generations allow it to do what?
# Predicted answer:
# Alternates from generation to generation
# 20
# Question : most of the chemical reactions in the body are facilitated by what?
# Predicted answer:
# Enzymes
# Question : most of the chemical reactions in the body are facilitated by what?
# Predicted answer:
# Enzymes
# 21
# Question : what is the termination of a pregnancy in progress called?
# Predicted answer:
# Transcription takes place in three steps initiation elongation and termination
# Question : what is the termination of a pregnancy in progress called?
# Predicted answer:
# Changes in the mothers body are required to expel the baby at the end of pregnancy and the events of childbirth once begun must progress rapidly to a conclusion or the life of the mother and the baby are at risk
# 22
# Question : cutting down on the use of chemical fertilizers and preserving wetlands are ways to prevent what unlivable regions in bodies of water?
# Predicted answer:
# Dead zones
# Question : cutting down on the use of chemical fertilizers and preserving wetlands are ways to prevent what unlivable regions in bodies of water?
# Predicted answer:
# Dead zones
# 23
# Question : which muscles allow your fingers to also make precise movements for actions?
# Predicted answer:
# Intrinsic muscles of the hand
# Question : which muscles allow your fingers to also make precise movements for actions?
# Predicted answer:
# Intrinsic muscles of the hand
# 24
# Question : testing what usually requires making observations or performing experiments?
# Predicted answer:
# A hypothesis
# Question : testing what usually requires making observations or performing experiments?
# Predicted answer:
# A hypothesis
# 25
# Question : this sharing of electrons produces what is known as a covalent bond covalent bonds are 20 to 50 times stronger than what?
# Predicted answer:
# Bonds in which atoms share rather than transfer electrons
# Question : this sharing of electrons produces what is known as a covalent bond covalent bonds are 20 to 50 times stronger than what?
# Predicted answer:
# Atoms
# 26
# Question : water molecules move about continuously due to what type of energy?
# Predicted answer:
# Kinetic
# Question : water molecules move about continuously due to what type of energy?
# Predicted answer:
# Kinetic
# 27
# Question : a small scale version of what type of map displays individual rock units?
# Predicted answer:
# Geologic maps
# Question : a small scale version of what type of map displays individual rock units?
# Predicted answer:
# Geologic maps
# 28
# Question : what is defined as a change in the inherited traits of organisms over time?
# Predicted answer:
# The theory of evolution
# Question : what is defined as a change in the inherited traits of organisms over time?
# Predicted answer:
# Evolution
# 29
# Question : what hormone which is associated with luteinizing hormone and male sexuality helps bring about physical changes in puberty?
# Predicted answer:
# Testosterone
# Question : what hormone which is associated with luteinizing hormone and male sexuality helps bring about physical changes in puberty?
# Predicted answer:
# Testosterone
# 30
# Question : where do angiosperms produce seeds in flowers?
# Predicted answer:
# Vascular tissue
# Question : where do angiosperms produce seeds in flowers?
# Predicted answer:
# In the ovaries
# 31
# Question : in order to create food what do photosynthetic protists use?
# Predicted answer:
# Light energy
# Question : in order to create food what do photosynthetic protists use?
# Predicted answer:
# Light energy
# 32
# Question : what type of vertebrates are birds?
# Predicted answer:
# Endothermic tetrapod vertebrates
# Question : what type of vertebrates are birds?
# Predicted answer:
# Endothermic tetrapod vertebrates
# 33
# Question : what type of ions do ionic compounds contain?
# Predicted answer:
# Positive ions and negative ions
# Question : what type of ions do ionic compounds contain?
# Predicted answer:
# Ions of metals and nonmetals
# 34
# Question : all living things need air and this to survive?
# Predicted answer:
# Temperature
# Question : all living things need air and this to survive?
# Predicted answer:
# Temperature
# 35
# Question : the cells of all eukarya have a what?
# Predicted answer:
# Nucleus and other organelles
# Question : the cells of all eukarya have a what?
# Predicted answer:
# Nucleus and other organelles
# 36
# Question : what type of plate boundaries produce huge mountain ranges in the ocean basin?
# Predicted answer:
# Divergent
# Question : what type of plate boundaries produce huge mountain ranges in the ocean basin?
# Predicted answer:
# Divergent
# 37
# Question : interstitial carbides are produced by the reaction of most transition metals at high temperatures with what element?
# Predicted answer:
# Carbon
# Question : interstitial carbides are produced by the reaction of most transition metals at high temperatures with what element?
# Predicted answer:
# Carbon
# 38
# Question : funguslike protist saprobes play what role in a food chain and are specialized to absorb nutrients from nonliving organic matter such as dead organisms or their wastes?
# Predicted answer:
# Generates sustenance for other organisms
# Question : funguslike protist saprobes play what role in a food chain and are specialized to absorb nutrients from nonliving organic matter such as dead organisms or their wastes?
# Predicted answer:
# Generates sustenance for other organisms
# 39
# Question : what are the sites of protein synthesis or assembly?
# Predicted answer:
# Ribosomes
# Question : what are the sites of protein synthesis or assembly?
# Predicted answer:
# Ribosomes
# 40
# Question : what must replicate in the cell cycle before meiosis i takes place?
# Predicted answer:
# Dna
# Question : what must replicate in the cell cycle before meiosis i takes place?
# Predicted answer:
# Dna
# 41
# Question : what phenomenon is primarily the result of plate tectonic motions?
# Predicted answer:
# Earthquakes
# Question : what phenomenon is primarily the result of plate tectonic motions?
# Predicted answer:
# Earthquakes
# 42
# Question : what is a group of neuron cell bodies in the periphery called?
# Predicted answer:
# Ganglia
# Question : what is a group of neuron cell bodies in the periphery called?
# Predicted answer:
# Ganglia
# 43
# Question : where does most of our food come from?
# Predicted answer:
# Craters and rifts become lakes
# Question : where does most of our food come from?
# Predicted answer:
# Craters and rifts become lakes
# 44
# Question : gases are most ideal at high temperature and what pressure?
# Predicted answer:
# Real gases deviate from ideal gases at high pressures and at low temperatures
# Question : gases are most ideal at high temperature and what pressure?
# Predicted answer:
# Low pressure
# 45
# Question : hard igneous rocks and easily dissolved sedimentary rocks respond very differently to what natural force?
# Predicted answer:
# Lava
# Question : hard igneous rocks and easily dissolved sedimentary rocks respond very differently to what natural force?
# Predicted answer:
# Weathering
# 46
# Question : a diet rich in calcium and what vitamin may reduce the risk of osteoporosis and related bone fractures?
# Predicted answer:
# Vitamin d
# Question : a diet rich in calcium and what vitamin may reduce the risk of osteoporosis and related bone fractures?
# Predicted answer:
# Vitamin d
# 47
# Question : how many people die from air pollution each year?
# Predicted answer:
# Almost 5 million
# Question : how many people die from air pollution each year?
# Predicted answer:
# Almost 5 million
# 48
# Question : what substances serve as catalysts in most of the biochemical reactions that take place in organisms?
# Predicted answer:
# Biochemical reactions are chemical reactions that take place inside the cells of organisms
# Question : what substances serve as catalysts in most of the biochemical reactions that take place in organisms?
# Predicted answer:
# Enzymes
# 49
# Question : the formation of an amalgam allows the metal to react with what?
# Predicted answer:
# Air and water
# Question : the formation of an amalgam allows the metal to react with what?
# Predicted answer:
# Air and water
# 50
# Question : a pulley changes the direction of the force t exerted by the cord without changing its what?
# Predicted answer:
# Magnitude
# Question : a pulley changes the direction of the force t exerted by the cord without changing its what?
# Predicted answer:
# Magnitude
# 51
# Question : what is the name of the small bumps that contain taste buds and covers the tongue?
# Predicted answer:
# Papillae
# Question : what is the name of the small bumps that contain taste buds and covers the tongue?
# Predicted answer:
# Papillae
# 52
# Question : in the absence of air resistance all falling objects accelerate at the same rate due to what force?
# Predicted answer:
# Gravity
# Question : in the absence of air resistance all falling objects accelerate at the same rate due to what force?
# Predicted answer:
# Gravity
# 53
# Question : the ability for a plasma membrane to only allow certain molecules in or out of the cell is referred to as what?
# Predicted answer:
# Selective permeability or semipermeability
# Question : the ability for a plasma membrane to only allow certain molecules in or out of the cell is referred to as what?
# Predicted answer:
# Selective permeability or semipermeability
# 54
# Question : in the presence of oxygen hydrogen can interact to make what?
# Predicted answer:
# Water
# Question : in the presence of oxygen hydrogen can interact to make what?
# Predicted answer:
# Water
# 55
# Question : what galaxy is our solar system a part of?
# Predicted answer:
# Milky way galaxy
# Question : what galaxy is our solar system a part of?
# Predicted answer:
# Milky way galaxy
# 56
# Question : the angle at which light bends when it enters a different medium is known as what?
# Predicted answer:
# Angle of refraction
# Question : the angle at which light bends when it enters a different medium is known as what?
# Predicted answer:
# Angle of refraction
# 57
# Question : whether the organism is a bacterium plant or animal all living things access energy by breaking down these?
# Predicted answer:
# Carbohydrate molecules
# Question : whether the organism is a bacterium plant or animal all living things access energy by breaking down these?
# Predicted answer:
# Carbohydrate molecules
# 58
# Question : increasing the temperature of n2 molecules increases what energy of motion?
# Predicted answer:
# Average kinetic energy
# Question : increasing the temperature of n2 molecules increases what energy of motion?
# Predicted answer:
# Average kinetic energy
# 59
# Question : which radio frequency should you listen to if you want less noise?
# Predicted answer:
# If you want to study insects what would you be called an entomologist if you want to study the tiny things that give us the flu then you need to enter the field of virology the study of viruses
# Question : which radio frequency should you listen to if you want less noise?
# Predicted answer:
# Fm
# 60
# Question : what form of radiation is the energy emitted by the sun?
# Predicted answer:
# Electromagnetic radiation
# Question : what form of radiation is the energy emitted by the sun?
# Predicted answer:
# Electromagnetic radiation
# 61
# Question : what is the suns innermost layer called?
# Predicted answer:
# The core
# Question : what is the suns innermost layer called?
# Predicted answer:
# The core
# 62
# Question : a growth spurt requires constant divisions of what?
# Predicted answer:
# Girls typically start their growth spurt a year or two earlier than boys and therefore a couple of centimeters
# Question : a growth spurt requires constant divisions of what?
# Predicted answer:
# Cell divisions
# 63
# Question : whats the term for the gradual progression from simple plants to larger more complex ones in an area?
# Predicted answer:
# Food chain
# Question : whats the term for the gradual progression from simple plants to larger more complex ones in an area?
# Predicted answer:
# Disaccharide
# 64
# Question : fungi may form mutualistic relationships with plants algae cyanobacteria and what?
# Predicted answer:
# Plants
# Question : fungi may form mutualistic relationships with plants algae cyanobacteria and what?
# Predicted answer:
# Ants
# 65
# Question : which cycle tracks the flow of nitrogen through an ecosystem?
# Predicted answer:
# The nitrogen cycle
# Question : which cycle tracks the flow of nitrogen through an ecosystem?
# Predicted answer:
# The nitrogen cycle
# 66
# Question : what consequence of a tornado is responsible for most injuries and deaths?
# Predicted answer:
# Flying debris
# Question : what consequence of a tornado is responsible for most injuries and deaths?
# Predicted answer:
# Flying debris
# 67
# Question : what are the only truly innate behaviors in humans called?
# Predicted answer:
# Reflex behaviors
# Question : what are the only truly innate behaviors in humans called?
# Predicted answer:
# Reflex behaviors
# 68
# Question : what happens to the density of air as the altitude decreases?
# Predicted answer:
# Air density and pressure change
# Question : what happens to the density of air as the altitude decreases?
# Predicted answer:
# The pressure of the air decreases
# 69
# Question : how do some animals change their depth?
# Predicted answer:
# Higher levels of organization
# Question : how do some animals change their depth?
# Predicted answer:
# Spin their complex webs without learning how to do it from other spiders
# 70
# Question : what phenomenon is crowding out other species and making all the other causes of extinction worse?
# Predicted answer:
# Human overpopulation
# Question : what phenomenon is crowding out other species and making all the other causes of extinction worse?
# Predicted answer:
# Human overpopulation
# 71
# Question : dessication is an extreme and usually fatal form of what in animals?
# Predicted answer:
# Dessication
# Question : dessication is an extreme and usually fatal form of what in animals?
# Predicted answer:
# Dessication is an extreme and usually fatal form of what in animals [sep] these brilliant red feathers are actually animals called tube worms
# 72
# Question : internal and external forms of what life process occur as simple diffusion due to a partial pressure gradient?
# Predicted answer:
# Internal respiration
# Question : internal and external forms of what life process occur as simple diffusion due to a partial pressure gradient?
# Predicted answer:
# Internal respiration
# 73
# Question : the fossil record shows that this type of event is followed by the evolution of new species to fill the habitats where old species lived?
# Predicted answer:
# Mass extinction
# Question : the fossil record shows that this type of event is followed by the evolution of new species to fill the habitats where old species lived?
# Predicted answer:
# Mass extinction
# 74
# Question : soluble minerals and clays accumulate in what soil layer allowing it to hold more water?
# Predicted answer:
# Subsoil
# Question : soluble minerals and clays accumulate in what soil layer allowing it to hold more water?
# Predicted answer:
# Subsoil
# 75
# Question : what is the common word for potential difference in a circuit?
# Predicted answer:
# Voltage
# Question : what is the common word for potential difference in a circuit?
# Predicted answer:
# Voltage
# 76
# Question : how many chambers does the stomach of a crocodile have?
# Predicted answer:
# ##4
# Question : how many chambers does the stomach of a crocodile have?
# Predicted answer:
# Four
# 77
# Question : when populations get close to the carrying capacity what happens to growth?
# Predicted answer:
# Overpopulation
# Question : when populations get close to the carrying capacity what happens to growth?
# Predicted answer:
# This is the biggest population the environment can support
# 78
# Question : although air can transfer heat rapidly by convection it is a poor conductor and thus a good what?
# Predicted answer:
# Insulator
# Question : although air can transfer heat rapidly by convection it is a poor conductor and thus a good what?
# Predicted answer:
# Insulator
# 79
# Question : most plants grow continuously except for what periods?
# Predicted answer:
# Periods 4 and 5 have 18 elements
# Question : most plants grow continuously except for what periods?
# Predicted answer:
# Drought
# 80
# Question : what manmade devices in space are used to observe the earths surface?
# Predicted answer:
# Orbiting satellites
# Question : what manmade devices in space are used to observe the earths surface?
# Predicted answer:
# Orbiting satellites
# 81
# Question : carboxylic acids are weak acids meaning they are not 100 ionized in what?
# Predicted answer:
# Water
# Question : carboxylic acids are weak acids meaning they are not 100 ionized in what?
# Predicted answer:
# Water
# 82
# Question : an endocrine disease usually involves the secretion of too much or not enough of what?
# Predicted answer:
# Hormone
# Question : an endocrine disease usually involves the secretion of too much or not enough of what?
# Predicted answer:
# Hormone
# 83
# Question : in experiments with garden peas austrian monk gregor mendel described the basic patterns of what?
# Predicted answer:
# Inheritance
# Question : in experiments with garden peas austrian monk gregor mendel described the basic patterns of what?
# Predicted answer:
# Inheritance
# 84
# Question : nutrition and diet affect your metabolism more energy is required to break down fats and proteins than this?
# Predicted answer:
# Carbohydrates
# Question : nutrition and diet affect your metabolism more energy is required to break down fats and proteins than this?
# Predicted answer:
# Carbohydrates
# 85
# Question : what are unsaturated hydrocarbons with at least one double bond between carbon atoms called?
# Predicted answer:
# Alkenes
# Question : what are unsaturated hydrocarbons with at least one double bond between carbon atoms called?
# Predicted answer:
# Alkenes
# 86
# Question : what is the opposite of melting?
# Predicted answer:
#
# Question : what is the opposite of melting?
# Predicted answer:
# Freezing
# 87
# Question : a unique characteristic of mammals is the ability to chew this happens by the temporalis and the masseter allowing what?
# Predicted answer:
# Sidetoside movement of the jaw
# Question : a unique characteristic of mammals is the ability to chew this happens by the temporalis and the masseter allowing what?
# Predicted answer:
# Sidetoside movement of the jaw
# 88
# Question : most of the pathogens that cause stis enter the body through mucous membranes of which organs?
# Predicted answer:
# Reproductive organs
# Question : most of the pathogens that cause stis enter the body through mucous membranes of which organs?
# Predicted answer:
# Reproductive organs
# 89
# Question : the activation of what kind of buds induces branching?
# Predicted answer:
# Exothermic reactions
# Question : the activation of what kind of buds induces branching?
# Predicted answer:
# Opossums
# 90
# Question : sexual reproduction involves haploid gametes and produces a diploid zygote through what process?
# Predicted answer:
# Fertilization
# Question : sexual reproduction involves haploid gametes and produces a diploid zygote through what process?
# Predicted answer:
# Fertilization
# 91
# Question : all alkanes are composed of carbon and hydrogen atoms and have similar bonds structures and formulas noncyclic alkanes all have a formula of cnh2n2 the number of carbon atoms present in an alkane has what?
# Predicted answer:
# No limit
# Question : all alkanes are composed of carbon and hydrogen atoms and have similar bonds structures and formulas noncyclic alkanes all have a formula of cnh2n2 the number of carbon atoms present in an alkane has what?
# Predicted answer:
# No limit
# 92
# Question : what percentage of men suffer from some form of erectile dysfunction by age 40?
# Predicted answer:
# What percentage of men suffer from some form of erectile dysfunction by age 40 [sep]
# Question : what percentage of men suffer from some form of erectile dysfunction by age 40?
# Predicted answer:
# 40 percent
# 93
# Question : what secures together immovable joints and prevents them from moving?
# Predicted answer:
# Very tough collagen
# Question : what secures together immovable joints and prevents them from moving?
# Predicted answer:
# Very tough collagen
# 94
# Question : transform faults are the site of massive what?
# Predicted answer:
# Earthquakes
# Question : transform faults are the site of massive what?
# Predicted answer:
# Earthquakes
# 95
# Question : when water goes above and below its freezing point what rockbreaking phenomenon is common?
# Predicted answer:
# Freezing the temperature at which a liquid changes to a solid is its freezing point the freezing point of water is 0c 32f other types of matter may have higher or lower freezing points
# Question : when water goes above and below its freezing point what rockbreaking phenomenon is common?
# Predicted answer:
# Ice wedging
# 96
# Question : the diatoms are unicellular photosynthetic protists that encase themselves in intricately patterned glassy cell walls composed of silicon dioxide in a matrix of organic particles these protists are a component of freshwater and these?
# Predicted answer:
# Marine plankton
# Question : the diatoms are unicellular photosynthetic protists that encase themselves in intricately patterned glassy cell walls composed of silicon dioxide in a matrix of organic particles these protists are a component of freshwater and these?
# Predicted answer:
# Marine plankton
# 97
# Question : what type of reactions form compounds?
# Predicted answer:
# Two or more elements combine chemically
# Question : what type of reactions form compounds?
# Predicted answer:
# Chemical reactions
# 98
# Question : millions of years ago plants used energy from the sun to form what?
# Predicted answer:
# Carbon compounds
# Question : millions of years ago plants used energy from the sun to form what?
# Predicted answer:
# Carbon compounds
# 99
# Question : what is the term for the process in which living things with beneficial traits produce more offspring than others do?
# Predicted answer:
# Natural selection
# Question : what is the term for the process in which living things with beneficial traits produce more offspring than others do?
# Predicted answer:
# Natural selection
# 100
# Question : in a chemical reaction the amounts of reactants and products will be constant when what state is attained?
# Predicted answer:
# Equilibrium
# Question : in a chemical reaction the amounts of reactants and products will be constant when what state is attained?
# Predicted answer:
# Equilibrium
# 101
# Question : what protects a developing flower while it is still a bud?
# Predicted answer:
# Sepals
# Question : what protects a developing flower while it is still a bud?
# Predicted answer:
# Sepals
# 102
# Question : what is the term for the force of attraction between things that have a mass?
# Predicted answer:
# Force of gravity
# Question : what is the term for the force of attraction between things that have a mass?
# Predicted answer:
# Force of gravity
# 103
# Question : what are the long thin protein extensions in most prokaryotic cells called?
# Predicted answer:
# Long thin protein extensions in most prokaryotic cells called [sep] prokaryotic cells are cells without a nucleus
# Question : what are the long thin protein extensions in most prokaryotic cells called?
# Predicted answer:
# Prokaryotes
# 104
# Question : dialysis is a treatment for failure of what organs?
# Predicted answer:
# Kidney
# Question : dialysis is a treatment for failure of what organs?
# Predicted answer:
# Kidneys
# 105
# Question : what preventive measure can protect even young children against diseases such as viral meningitis?
# Predicted answer:
# Vaccinated
# Question : what preventive measure can protect even young children against diseases such as viral meningitis?
# Predicted answer:
# Vaccinated
# 106
# Question : renal plasma flow equals the blood flow per minute times the what?
# Predicted answer:
# Hematocrit
# Question : renal plasma flow equals the blood flow per minute times the what?
# Predicted answer:
# Hematocrit
# 107
# Question : what does lattice energy of an ionic solid measure the strength of?
# Predicted answer:
# Bonds in that ionic compound
# Question : what does lattice energy of an ionic solid measure the strength of?
# Predicted answer:
# Bonds in that ionic compound
# 108
# Question : how many different types of taste can be detected by taste buds?
# Predicted answer:
# Five
# Question : how many different types of taste can be detected by taste buds?
# Predicted answer:
# Five
# 109
# Question : what species do humans belong to?
# Predicted answer:
# Lions
# Question : what species do humans belong to?
# Predicted answer:
# Birds
# 110
# Question : titration is a method to determine what in acids or bases?
# Predicted answer:
# Strong acid with a strong base
# Question : titration is a method to determine what in acids or bases?
# Predicted answer:
# Equivalence point
# 111
# Question : how many different amino acids make up proteins?
# Predicted answer:
# Proteins can differ from one another in the number and sequence order of amino acids it is because of the side chains of the amino acids that proteins with different amino acid sequences have different shapes and different chemical properties small proteins can contain just a few hundred amino acids yeast proteins average 466 amino acids
# Question : how many different amino acids make up proteins?
# Predicted answer:
# 20 different amino acids
# 112
# Question : what are sores in the lining of the stomach or duodenum that are usually caused by bacterial infections or acidity?
# Predicted answer:
# Ulcers
# Question : what are sores in the lining of the stomach or duodenum that are usually caused by bacterial infections or acidity?
# Predicted answer:
# Ulcers
# 113
# Question : in some species what has led to the evolution of alternative male mating behavior and morphology?
# Predicted answer:
#
# Question : in some species what has led to the evolution of alternative male mating behavior and morphology?
# Predicted answer:
# Males in some species of whales have special mating songs
# 114
# Question : what structure is made from dna and protein molecules coiled together?
# Predicted answer:
# Protein structure the structure of a protein starts with its sequence of amino acids what determines the secondary structure
# Question : what structure is made from dna and protein molecules coiled together?
# Predicted answer:
# Chromosomes
# 115
# Question : what renewable energy source converts energy from the sunlight into electricity?
# Predicted answer:
# Solar cells
# Question : what renewable energy source converts energy from the sunlight into electricity?
# Predicted answer:
# Solar panels
# 116
# Question : the radial artery and which artery parallel their namesake bones giving off smaller branches until they reach the wrist or carpal region?
# Predicted answer:
# Ulnar artery
# Question : the radial artery and which artery parallel their namesake bones giving off smaller branches until they reach the wrist or carpal region?
# Predicted answer:
# Ulnar artery
# 117
# Question : the bones of the skull are connected by what type of joints?
# Predicted answer:
# Immovable
# Question : the bones of the skull are connected by what type of joints?
# Predicted answer:
# Immovable
# 118
# Question : what is the lowest layer of the atmosphere?
# Predicted answer:
# The troposphere
# Question : what is the lowest layer of the atmosphere?
# Predicted answer:
# The troposphere
# 119
# Question : what is the name of the type of plant tissue consisting of undifferentiated cells that can continue to divide and differentiate?
# Predicted answer:
# Meristem meristem
# Question : what is the name of the type of plant tissue consisting of undifferentiated cells that can continue to divide and differentiate?
# Predicted answer:
# Meristem
# 120
# Question : phosphatecontaining ocean sediments form primarily from the bodies of ocean organisms and from their what?
# Predicted answer:
# Excretions
# Question : phosphatecontaining ocean sediments form primarily from the bodies of ocean organisms and from their what?
# Predicted answer:
# Excretions
# 121
# Question : what does erosion do to pieces of broken rock?
# Predicted answer:
# Moves
# Question : what does erosion do to pieces of broken rock?
# Predicted answer:
# Moves
# 122
# Question : the passing of traits from parents to offspring is done through what?
# Predicted answer:
# Before gregor mendels research
# Question : the passing of traits from parents to offspring is done through what?
# Predicted answer:
# Dna
# 123
# Question : in a glass of sweet tea the sugar is known as the solute and the water is known as what?
# Predicted answer:
# Solvent
# Question : in a glass of sweet tea the sugar is known as the solute and the water is known as what?
# Predicted answer:
# Solvent
# 124
# Question : a few earthquakes take place away from plate boundaries these are called what?
# Predicted answer:
# Intraplate earthquakes
# Question : a few earthquakes take place away from plate boundaries these are called what?
# Predicted answer:
# Intraplate earthquakes
# 125
# Question : red litmus paper turns what color when placed in a basic solution?
# Predicted answer:
# Blue
# Question : red litmus paper turns what color when placed in a basic solution?
# Predicted answer:
# Blue
# 126
# Question : the difference between the theoretical halfreaction reduction potential and the actual voltage required is called what?
# Predicted answer:
# Overpotential
# Question : the difference between the theoretical halfreaction reduction potential and the actual voltage required is called what?
# Predicted answer:
# Overpotential
# 127
# Question : while the egg is developing other changes are taking place in the uterus it develops a thick lining that is full of what?
# Predicted answer:
# Tiny blood vessels
# Question : while the egg is developing other changes are taking place in the uterus it develops a thick lining that is full of what?
# Predicted answer:
# Tiny blood vessels
# 128
# Question : the neural plate undergoes a series of cell movements where it rolls up and forms a tube called what?
# Predicted answer:
# The neural tube
# Question : the neural plate undergoes a series of cell movements where it rolls up and forms a tube called what?
# Predicted answer:
# The neural tube
# 129
# Question : due to the __________ nature of the lipids that make up cell membranes polar molecules such as water and ions cannot easily diffuse across the cell membrane?
# Predicted answer:
# Hydrophobic
# Question : due to the __________ nature of the lipids that make up cell membranes polar molecules such as water and ions cannot easily diffuse across the cell membrane?
# Predicted answer:
# Hydrophobic
# 130
# Question : in what way do all vertebrates reproduce?
# Predicted answer:
# Vertebrates have a notochord a dorsal hollow nerve cord pharyngeal slits and a postanal tail
# Question : in what way do all vertebrates reproduce?
# Predicted answer:
# Sexually
# 131
# Question : first high temperature denatures proteins and does what to cells?
# Predicted answer:
# Speed up chemical reactions in cells enzymes interact with the substrates reactants of a biochemical reaction helping the reaction proceed at a much faster rate other proteins are antibodies that protect you from pathogens antibodies bond to foreign substances in the body and target them for destruction
# Question : first high temperature denatures proteins and does what to cells?
# Predicted answer:
# Bacteria that survive in hot springs have proteins that function at temperatures close to boiling the stomach is also very acidic has a low ph and denatures proteins as part of the digestion process
# 132
# Question : what term is used to describe a collection of molecules surrounded by a phospholipid bilayer that is capable of reproducing itself?
# Predicted answer:
# A cell
# Question : what term is used to describe a collection of molecules surrounded by a phospholipid bilayer that is capable of reproducing itself?
# Predicted answer:
# A cell
# 133
# Question : by allowing blood levels of a hormone to be regulated within a narrow range feedback loops contribute to maintaining what state?
# Predicted answer:
# Homeostasis
# Question : by allowing blood levels of a hormone to be regulated within a narrow range feedback loops contribute to maintaining what state?
# Predicted answer:
# Homeostasis
# 134
# Question : collagen fibers elastic fibers and reticular fibers comprise what type of tissue?
# Predicted answer:
# Connective tissue
# Question : collagen fibers elastic fibers and reticular fibers comprise what type of tissue?
# Predicted answer:
# Connective tissue
# 135
# Question : what the name of the disease where some of the alveoli of the lungs fill with fluid so they can no longer exchange gas?
# Predicted answer:
# Pneumonia
# Question : what the name of the disease where some of the alveoli of the lungs fill with fluid so they can no longer exchange gas?
# Predicted answer:
# Pneumonia
# 136
# Question : what occurs when groups from the same species stop mating because of something other than physical or geographic separation?
# Predicted answer:
# Sympatric speciation
# Question : what occurs when groups from the same species stop mating because of something other than physical or geographic separation?
# Predicted answer:
# Sympatric speciation
# 137
# Question : what environment do animals with gills live in?
# Predicted answer:
# Water
# Question : what environment do animals with gills live in?
# Predicted answer:
# Deep ocean floor
# 138
# Question : what is the boiling and freezing point of water in celcius?
# Predicted answer:
# Boiling point of a solution is higher than the boiling point of the pure solvent
# Question : what is the boiling and freezing point of water in celcius?
# Predicted answer:
# Greater than 100c
# 139
# Question : what are living things that obtain glucose by eating self feeders called?
# Predicted answer:
# Heterotrophs
# Question : what are living things that obtain glucose by eating self feeders called?
# Predicted answer:
# Heterotrophs
# 140
# Question : virtually every task performed by living organisms requires this?
# Predicted answer:
# Biology of cells to the biology of individual organisms to how these organisms interact with other organisms and their environment
# Question : virtually every task performed by living organisms requires this?
# Predicted answer:
# Energy
# 141
# Question : the binding of what helps eliminate antigens by phagocytosis and complementmediated lysis?
# Predicted answer:
#
# Question : the binding of what helps eliminate antigens by phagocytosis and complementmediated lysis?
# Predicted answer:
# Antibody is a large yshaped protein that binds to an antigen a protein that is recognized as foreign antigens are found on the outside of bacteria viruses and other foreign microorganisms each antibody can bind with just one specific type of antigen figure below they fit together like a lock and key once an antigen and antibody
# 142
# Question : what muscles are used to pump water over the gills?
# Predicted answer:
# Gills are organs behind the head that absorb oxygen from water water enters through the mouth
# Question : what muscles are used to pump water over the gills?
# Predicted answer:
# Gills
# 143
# Question : compounds like sodium chloride form structures called what?
# Predicted answer:
# Crystals
# Question : compounds like sodium chloride form structures called what?
# Predicted answer:
# Crystals
# 144
# Question : what are made of long chains consisting almost solely of carbon and hydrogen?
# Predicted answer:
# Lipids
# Question : what are made of long chains consisting almost solely of carbon and hydrogen?
# Predicted answer:
# Lipids
# 145
# Question : when a series of measurements is precise but not what the error is usually systematic?
# Predicted answer:
# Accurate
# Question : when a series of measurements is precise but not what the error is usually systematic?
# Predicted answer:
# Accurate
# 146
# Question : inserting copies of normal genes into a patient with defective genes is known as?
# Predicted answer:
# Inserting copies of normal genes into a patient with defective genes is known as [sep] genes located on the sex chromosomes are called sexlinked genes
# Question : inserting copies of normal genes into a patient with defective genes is known as?
# Predicted answer:
# Gene therapy
# 147
# Question : what type of reproduction usually occur during times of environmental stress?
# Predicted answer:
# Vegetative reproduction
# Question : what type of reproduction usually occur during times of environmental stress?
# Predicted answer:
# Environmental stress [sep] earthquakes are primarily the result of plate tectonic motions what type of stress would cause earthquakes
# 148
# Question : all forms of energy can be interconverted three things can change the energy of an object the transfer of heat work performed on or by an object or some combination of what?
# Predicted answer:
# Heat and work
# Question : all forms of energy can be interconverted three things can change the energy of an object the transfer of heat work performed on or by an object or some combination of what?
# Predicted answer:
# Heat and work
# 149
# Question : what science includes many fields of science related to our home planet?
# Predicted answer:
# Earth science
# Question : what science includes many fields of science related to our home planet?
# Predicted answer:
# Earth science
# 150
# Question : what are alloys that are mostly composed of mercury known as?
# Predicted answer:
# Amalgams
# Question : what are alloys that are mostly composed of mercury known as?
# Predicted answer:
# Amalgams
# 151
# Question : what are made from highly reflective metal that is applied to a curved or flat piece of glass?
# Predicted answer:
# Mirrors
# Question : what are made from highly reflective metal that is applied to a curved or flat piece of glass?
# Predicted answer:
# Mirrors
# 152
# Question : what do ranchers fear will happen if wolves return?
# Predicted answer:
#
# Question : what do ranchers fear will happen if wolves return?
# Predicted answer:
#
# 153
# Question : how many types of surface waves are there?
# Predicted answer:
# Three
# Question : how many types of surface waves are there?
# Predicted answer:
# Three
# 154
# Question : what is the rigid layer that is found outside the cell membrane and surrounds the cell?
# Predicted answer:
# The cell membrane
# Question : what is the rigid layer that is found outside the cell membrane and surrounds the cell?
# Predicted answer:
# A cell wall
# 155
# Question : surface tension of alveolar fluid which is mostly water creates an inward pull of the tissue of what organ?
# Predicted answer:
# Lung
# Question : surface tension of alveolar fluid which is mostly water creates an inward pull of the tissue of what organ?
# Predicted answer:
# Lung
# 156
# Question : what type of tumor mostly does not cause serious problems and can be completely removed by surgery?
# Predicted answer:
# Metamorphism
# Question : what type of tumor mostly does not cause serious problems and can be completely removed by surgery?
# Predicted answer:
# Utis
# 157
# Question : what supports and protects the soft organs of the body?
# Predicted answer:
# The skeletal system
# Question : what supports and protects the soft organs of the body?
# Predicted answer:
# Protection the skeleton
# 158
# Question : what celestial body is the earths main source of energy?
# Predicted answer:
# The sun
# Question : what celestial body is the earths main source of energy?
# Predicted answer:
# The sun
# 159
# Question : what do you call the horizontal stems of a strawberry plant that run over the ground surface?
# Predicted answer:
# Stolons
# Question : what do you call the horizontal stems of a strawberry plant that run over the ground surface?
# Predicted answer:
# Stolons
# 160
# Question : glaciers are incredibly powerful agents of what?
# Predicted answer:
# Erosion
# Question : glaciers are incredibly powerful agents of what?
# Predicted answer:
# Erosion
# 161
# Question : what type of pressure is the pressure exerted by gas particles in earths atmosphere as those particles collide with objects?
# Predicted answer:
# Gas pressure
# Question : what type of pressure is the pressure exerted by gas particles in earths atmosphere as those particles collide with objects?
# Predicted answer:
# Gas pressure
# 162
# Question : what helps the plasma membrane keep its shape?
# Predicted answer:
# Molecules of cholesterol
# Question : what helps the plasma membrane keep its shape?
# Predicted answer:
# Molecules of cholesterol
# 163
# Question : what type of reproduction only involves one parent?
# Predicted answer:
# Asexual
# Question : what type of reproduction only involves one parent?
# Predicted answer:
# Asexual
# 164
# Question : what is defined as a repeating series of events that include growth dna synthesis and cell division?
# Predicted answer:
# Cell cycle
# Question : what is defined as a repeating series of events that include growth dna synthesis and cell division?
# Predicted answer:
# Cell cycle
# 165
# Question : how metalloids behave in chemical interactions with other elements depends mainly on the number of what in the outer energy level of their atoms?
# Predicted answer:
# Electrons
# Question : how metalloids behave in chemical interactions with other elements depends mainly on the number of what in the outer energy level of their atoms?
# Predicted answer:
# Electrons
# 166
# Question : what distinguishing characteristic of annelid anatomy shows specialization and adaptation?
# Predicted answer:
# Specialization lets different species of anole lizards live in the same area without competing
# Question : what distinguishing characteristic of annelid anatomy shows specialization and adaptation?
# Predicted answer:
# Dynamic
# 167
# Question : the spermatids are transported from the testes to where?
# Predicted answer:
# The epididymis
# Question : the spermatids are transported from the testes to where?
# Predicted answer:
# The epididymis
# 168
# Question : how does water from roots reach the leaves?
# Predicted answer:
# Stems
# Question : how does water from roots reach the leaves?
# Predicted answer:
# Stems
# 169
# Question : as a polycrystalline material solidifies grains with irregular shapes form the interfaces between grains constitute grain what?
# Predicted answer:
# Grain boundaries
# Question : as a polycrystalline material solidifies grains with irregular shapes form the interfaces between grains constitute grain what?
# Predicted answer:
# Grain boundaries
# 170
# Question : motors are the most common application of magnetic force on currentcarrying wires motors have loops of wire in this?
# Predicted answer:
# A magnetic field
# Question : motors are the most common application of magnetic force on currentcarrying wires motors have loops of wire in this?
# Predicted answer:
# A magnetic field
# 171
# Question : what makes and stores pigments that give petals and fruit their orange and yellow colors?
# Predicted answer:
# Chromoplasts
# Question : what makes and stores pigments that give petals and fruit their orange and yellow colors?
# Predicted answer:
# Chromoplasts
# 172
# Question : what term is used to describe when a liquid is the temperature at which its equilibrium vapor pressure is equal to the pressure exerted on the liquid by its gaseous surroundings?
# Predicted answer:
# Boiling point
# Question : what term is used to describe when a liquid is the temperature at which its equilibrium vapor pressure is equal to the pressure exerted on the liquid by its gaseous surroundings?
# Predicted answer:
# Boiling point
# 173
# Question : when electrons return to a lower energy level they emit the excess energy in the form of what?
# Predicted answer:
# ...
# Sexual reproduction
# 216
# Question : global warming will raise ocean levels due to melt water from glaciers and the greater volume of what?
# Predicted answer:
# Climate change in earth history was due to natural processes recent global warming is due mainly to human actions the burning of fossil fuels releases greenhouse gases into the air this creates greater greenhouse effect
# Question : global warming will raise ocean levels due to melt water from glaciers and the greater volume of what?
# Predicted answer:
# Warmer water
# 217
# Question : what are groups of young stars loosely held together by gravity called?
# Predicted answer:
# Open clusters
# Question : what are groups of young stars loosely held together by gravity called?
# Predicted answer:
# Open clusters
# 218
# Question : what does a pollinator pick up from its body and carry directly to another plant of the same species?
# Predicted answer:
# Pollen
# Question : what does a pollinator pick up from its body and carry directly to another plant of the same species?
# Predicted answer:
# Pollen
# 219
# Question : what is formed when an oxygen atom picks up a pair of hydrogen ions from a solution?
# Predicted answer:
# Blood
# Question : what is formed when an oxygen atom picks up a pair of hydrogen ions from a solution?
# Predicted answer:
# A molecule of water
# 220
# Question : what does the driving of turbines by the heating of water to steam accomplish?
# Predicted answer:
# Turn generators and the generators create electricity
# Question : what does the driving of turbines by the heating of water to steam accomplish?
# Predicted answer:
# Turn generators and the generators create electricity
# 221
# Question : what is a device that changes kinetic energy to electrical energy through electromagnetic induction?
# Predicted answer:
# An electric generator
# Question : what is a device that changes kinetic energy to electrical energy through electromagnetic induction?
# Predicted answer:
# An electric generator
# 222
# Question : how many naturally occurring elements are known on earth?
# Predicted answer:
# 92
# Question : how many naturally occurring elements are known on earth?
# Predicted answer:
# About 90
# 223
# Question : what are the two types of vesicle transport called?
# Predicted answer:
# Endocytosis and exocytosis
# Question : what are the two types of vesicle transport called?
# Predicted answer:
# Exocytosis and endocytosis
# 224
# Question : what do you call a species that has died out in the past?
# Predicted answer:
# Extinct
# Question : what do you call a species that has died out in the past?
# Predicted answer:
#
# 225
# Question : where does the embryo develop in a plant?
# Predicted answer:
# Inside a seed
# Question : where does the embryo develop in a plant?
# Predicted answer:
# Inside a seed
# 226
# Question : what is the method of setting or correcting a measuring device by matching it to known measurement standards called?
# Predicted answer:
# Calibration
# Question : what is the method of setting or correcting a measuring device by matching it to known measurement standards called?
# Predicted answer:
# Calibration
# 227
# Question : what property of warm air causes it to rise above cold air?
# Predicted answer:
# Moving faster
# Question : what property of warm air causes it to rise above cold air?
# Predicted answer:
# Moving faster
# 228
# Question : which branch of biology studies animal behavior?
# Predicted answer:
# Ethology
# Question : which branch of biology studies animal behavior?
# Predicted answer:
# Ethology
# 229
# Question : what unit of measure is equal to the amount of work a horse can do in 1 minute?
# Predicted answer:
# Horsepower
# Question : what unit of measure is equal to the amount of work a horse can do in 1 minute?
# Predicted answer:
# Horsepower
# 230
# Question : what organism is characterized by an incomplete digestive system and a single tentacled opening?
# Predicted answer:
# Flatworms
# Question : what organism is characterized by an incomplete digestive system and a single tentacled opening?
# Predicted answer:
# Cnidarians
# 231
# Question : what term is not the same as energy but means the energy per unit charge?
# Predicted answer:
# Unable to find the answer to your question.
# Question : what term is not the same as energy but means the energy per unit charge?
# Predicted answer:
# Voltage
# 232
# Question : what specific part of the african violet is used to propagate other plants?
# Predicted answer:
# Roots
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 5
#       3 context_lst = find_context(dataset['question'][index])
#       4 answer_1 = question_answer(dataset['question'][index],context_lst[0])
# ----> 5 answer_2 = question_answer(dataset['question'][index],context_lst[1])
#       6 if answer_1 == dataset['correct_answer'][index]:
#       7     score_1 +=1
#
# Cell In[26], line 21, in question_answer(question, text)
#      18 assert len(segment_ids) == len(input_ids)
#      20 #model output using input_ids and segment_ids
# ---> 21 output = model(torch.tensor([input_ids]), token_type_ids=torch.tensor([segment_ids]))
#      23 #reconstructing the answer
#      24 answer_start = torch.argmax(output.start_logits)
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\ANACONDA\lib\site-packages\transformers\models\bert\modeling_bert.py:1843, in BertForQuestionAnswering.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, start_positions, end_positions, output_attentions, output_hidden_states, return_dict)
#    1831 r"""
#    1832 start_positions (`torch.LongTensor` of shape `(batch_size,)`, *optional*):
#    1833     Labels for position (index) of the start of the labelled span for computing the token classification loss.
#    (...)
#    1839     are not taken into account for computing the loss.
#    1840 """
#    1841 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1843 outputs = self.bert(
#    1844     input_ids,
#    1845     attention_mask=attention_mask,
#    1846     token_type_ids=token_type_ids,
#    1847     position_ids=position_ids,
#    1848     head_mask=head_mask,
#    1849     inputs_embeds=inputs_embeds,
#    1850     output_attentions=output_attentions,
#    1851     output_hidden_states=output_hidden_states,
#    1852     return_dict=return_dict,
#    1853 )
#    1855 sequence_output = outputs[0]
#    1857 logits = self.qa_outputs(sequence_output)
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\ANACONDA\lib\site-packages\transformers\models\bert\modeling_bert.py:1014, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1005 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#    1007 embedding_output = self.embeddings(
#    1008     input_ids=input_ids,
#    1009     position_ids=position_ids,
#    (...)
#    1012     past_key_values_length=past_key_values_length,
#    1013 )
# -> 1014 encoder_outputs = self.encoder(
#    1015     embedding_output,
#    1016     attention_mask=extended_attention_mask,
#    1017     head_mask=head_mask,
#    1018     encoder_hidden_states=encoder_hidden_states,
#    1019     encoder_attention_mask=encoder_extended_attention_mask,
#    1020     past_key_values=past_key_values,
#    1021     use_cache=use_cache,
#    1022     output_attentions=output_attentions,
#    1023     output_hidden_states=output_hidden_states,
#    1024     return_dict=return_dict,
#    1025 )
#    1026 sequence_output = encoder_outputs[0]
#    1027 pooled_output = self.pooler(sequence_output) if self.pooler is not None else None
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\ANACONDA\lib\site-packages\transformers\models\bert\modeling_bert.py:603, in BertEncoder.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     594     layer_outputs = torch.utils.checkpoint.checkpoint(
#     595         create_custom_forward(layer_module),
#     596         hidden_states,
#    (...)
#     600         encoder_attention_mask,
#     601     )
#     602 else:
# --> 603     layer_outputs = layer_module(
#     604         hidden_states,
#     605         attention_mask,
#     606         layer_head_mask,
#     607         encoder_hidden_states,
#     608         encoder_attention_mask,
#     609         past_key_value,
#     610         output_attentions,
#     611     )
#     613 hidden_states = layer_outputs[0]
#     614 if use_cache:
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\ANACONDA\lib\site-packages\transformers\models\bert\modeling_bert.py:489, in BertLayer.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     477 def forward(
#     478     self,
#     479     hidden_states: torch.Tensor,
#    (...)
#     486 ) -> Tuple[torch.Tensor]:
#     487     # decoder uni-directional self-attention cached key/values tuple is at positions 1,2
#     488     self_attn_past_key_value = past_key_value[:2] if past_key_value is not None else None
# --> 489     self_attention_outputs = self.attention(
#     490         hidden_states,
#     491         attention_mask,
#     492         head_mask,
#     493         output_attentions=output_attentions,
#     494         past_key_value=self_attn_past_key_value,
#     495     )
#     496     attention_output = self_attention_outputs[0]
#     498     # if decoder, the last output is tuple of self-attn cache
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\ANACONDA\lib\site-packages\transformers\models\bert\modeling_bert.py:419, in BertAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     409 def forward(
#     410     self,
#     411     hidden_states: torch.Tensor,
#    (...)
#     417     output_attentions: Optional[bool] = False,
#     418 ) -> Tuple[torch.Tensor]:
# --> 419     self_outputs = self.self(
#     420         hidden_states,
#     421         attention_mask,
#     422         head_mask,
#     423         encoder_hidden_states,
#     424         encoder_attention_mask,
#     425         past_key_value,
#     426         output_attentions,
#     427     )
#     428     attention_output = self.output(self_outputs[0], hidden_states)
#     429     outputs = (attention_output,) + self_outputs[1:]  # add attentions if we output them
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\ANACONDA\lib\site-packages\transformers\models\bert\modeling_bert.py:308, in BertSelfAttention.forward(self, hidden_states, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, past_key_value, output_attentions)
#     306 else:
#     307     key_layer = self.transpose_for_scores(self.key(hidden_states))
# --> 308     value_layer = self.transpose_for_scores(self.value(hidden_states))
#     310 query_layer = self.transpose_for_scores(mixed_query_layer)
#     312 if self.is_decoder:
#     313     # if cross_attention save Tuple(torch.Tensor, torch.Tensor) of all cross attention key/value_states.
#     314     # Further calls to cross_attention layer can then reuse all cross-attention
#    (...)
#     318     # can concat previous decoder key/value_states to current projected key/value_states (third "elif" case)
#     319     # if encoder bi-directional self-attention `past_key_value` is always `None`
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\ANACONDA\lib\site-packages\torch\nn\modules\linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
