# %% [markdown]
# # Language Modeling using Ngram

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
shutil.copy("/content/drive/MyDrive/FRA 501 IntroNLP&DL/Dataset/BEST2010.zip", "/content/BEST2010.zip")
# Out:
# '/content/BEST2010.zip'

# %%
# !unzip BEST2010.zip
# Out:
# Archive:  BEST2010.zip
#    creating: BEST2010/
#   inflating: BEST2010/article.txt
#   inflating: BEST2010/encyclopedia.txt
#   inflating: BEST2010/news.txt

# %%
#First we import necessary library such as math, nltk, bigram, and collections.
import math
import nltk
import io
import random
from random import shuffle
from collections import defaultdict
random.seed(999)

# %% [markdown]
# BEST2010 is a free Thai NLP dataset by NECTEC usually use as a standard benchmark for various NLP tasks includeing language modeling. BEST2010 is separated into 4 domain article, encyclopedia, news and novel. The data is already  tokenized using '|' as a separator.
#
# For example,
#
# ตาม|ที่|นางประนอม ทองจันทร์| |กับ| |ด.ช.กิตติพงษ์ แหลมผักแว่น| |และ| |ด.ญ.กาญจนา กรองแก้ว| |ป่วย|สงสัย|ติด|เชื้อ|ไข้|ขณะ|นี้|ยัง|ไม่|ดี|ขึ้น|

# %%
# We choose news domain as our dataset
best2010=[]
fp= io.open('BEST2010/news.txt','r',encoding='utf-8')
for i,line in enumerate(fp):
    best2010.append(line.strip()[:-1])
fp.close()
all_vocabulary =set()
total_word_count =0
for line in best2010:
    for word in line.split('|'):        
        all_vocabulary.add(word)
        total_word_count+=1

# %%
best2010[0]
# Out:
# 'สงสัย|ติด|หวัด|นก| |อีก|คน|ยัง|น่า|ห่วง'

# %%
best2010[1]
# Out:
# 'ตาม|ที่|นางประนอม ทองจันทร์| |กับ| |ด.ช.กิตติพงษ์ แหลมผักแว่น| |และ| |ด.ญ.กาญจนา กรองแก้ว| |ป่วย|สงสัย|ติด|เชื้อ|ไข้|ขณะ|นี้|ยัง|ไม่|ดี|ขึ้น'

# %%
#For simplicity, we assumes that each line is a sentence.
print ('Total sentences in BEST2010 news dataset :\t'+ str(len(best2010)))
print ('Total word counts in BEST2010 news dataset :\t'+ str(total_word_count))
print ('Total vocabulary in BEST2010 news dataset :\t'+ str(len(all_vocabulary)))
# Out:
# Total sentences in BEST2010 news dataset :	30969
# Total word counts in BEST2010 news dataset :	1660190
# Total vocabulary in BEST2010 news dataset :	35488

# %% [markdown]
# We separate out input into 2 sets, train and test data with 70:30 ratio

# %%
sentences = best2010
# The data is separated to train and test set with 70:30 ratio.
train = sentences[:int(len(sentences)*0.7)]
test = sentences[int(len(sentences)*0.7):]

#Training data
train_vocabulary =set()
train_word_count =0
for line in train:
    for word in line.split('|'):        
        train_vocabulary.add(word)
        train_word_count+=1
print ('Total sentences in BEST2010 news training dataset :\t'+ str(len(train)))
print ('Total word counts in BEST2010 news training dataset :\t'+ str(train_word_count))
print ('Total vocabuary in BEST2010 news training dataset :\t'+ str(len(train_vocabulary)))
# We will use 1/vocab_size as a default value for unknown word
unk_value = math.pow(len(train_vocabulary),-1)
# Out:
# Total sentences in BEST2010 news training dataset :	21678
# Total word counts in BEST2010 news training dataset :	1042797
# Total vocabuary in BEST2010 news training dataset :	26240

# %%
print(unk_value)
# Out:
# 3.8109756097560976e-05

# %%
train[:10]
# Out:
# ['สงสัย|ติด|หวัด|นก| |อีก|คน|ยัง|น่า|ห่วง',
#  'ตาม|ที่|นางประนอม ทองจันทร์| |กับ| |ด.ช.กิตติพงษ์ แหลมผักแว่น| |และ| |ด.ญ.กาญจนา กรองแก้ว| |ป่วย|สงสัย|ติด|เชื้อ|ไข้|ขณะ|นี้|ยัง|ไม่|ดี|ขึ้น',
#  'หลัง|เข้า|เยี่ยม|ดู|อาการ|ผู้|ป่วย|แล้ว| |น.พ.จรัล|ประชุม|ร่วม|กับ|เจ้าหน้าที่|ทุก|ฝ่าย| |เพื่อ|สรุป|ผล|การ|ดำเนิน|การ| |รวม|ทั้ง|สอบสวน|โรค|ก่อน|ที่|ผู้|ป่วย|จะ|ถูก|ส่ง|มา|รักษา|ตัว| |จาก|นั้น|ร่วม|กัน|แถลง|ข่าว| |โดย| |น.พ.จรัล|กล่าว|ว่า| |ขณะ|นี้|ผู้|ป่วย|ทั้ง| |3| |ราย| |อาการ|ยัง|ทรง| |โดย|ใน|ราย|ของ| |ด.ช.กิตติพงษ์| |กับ| |ด.ญ.กาญจนา| |ปอด|หาย|เป็น|ปกติ|แล้ว| |คาด|ว่า|จะ|กลับ|บ้าน|ได้|ใน|ไม่|ช้า|นี้| |แต่|ใน|ราย|ของ|นางประนอม|อาการ|ยัง|น่า|เป็นห่วง| |ซึ่ง|ทั้ง| |3| |ราย| |ใน|ชั้น|นี้|ถือ|ว่า|เป็น|ผู้|ป่วย|อยู่|ใน|ขั้น|น่า|สงสัย|อาจ|ติด|เชื้อ|ไข้|หวัด|นก| |เพราะ|ตรวจ|พบ|ผู้|ป่วย|มี|อาการ|ปอด|บวม|ปอด|อักเสบ| |เนื่อง|จาก|ติด|เชื้อ|ไวรัส| |แต่|ยัง|สรุป|ไม่|ได้|ว่า|ติด|เชื้อ|ไข้|หวัด|นก|แน่ชัด|หรือ|ไม่| |ต้อง|รอ|ผล|ตรวจ|จาก|ห้อง|ปฏิบัติการ|ที่|ได้|ส่ง|ตัวอย่าง|เลือด| |ไป|ตรวจ|พิสูจน์|ที่|กรมวิทยาศาสตร์การแพทย์กระทรวงสาธารณสุข| |และ| |รพ.ศิริราช| |ซึ่ง|จะ|ทราบ|ผล|ใน|วัน|สอง|วัน|นี้',
#  'น.พ.จรัล| |กล่าว|ต่อ|ว่า| |จาก|การ|สอบสวน|โรค|พบ|ว่า| |ผู้|ที่|เสีย|ชีวิต|ก่อนหน้า|นี้| |3| |ราย| |กับ|ผู้|ป่วย|ที่|อยู่|ใน|ข่าย|น่า|สงสัย|อีก| |3| |ราย| |มี|ประวัติ|สัมผัส|ไก่|ที่|ตาย|ด้วย|โรค|ไข้|หวัด|นก|ใน|เขต| |อ.ขาณุวรลักษบุรี| |และ|เขตกิ่งอ.โกสัมพีนคร| |ส่วน|ที่|มี|การ|ระแวง|กัน|ว่า|เชื้อ|ไข้|หวัด|นก|จะ|กลาย|พันธุ์|ระบาด|จาก|คน|สู่|คน|นั้น| |น.พ.จรัล|กล่าว|ว่า| |ยัง|ไม่|มี|ประวัติ| |และ|ยัง|ไม่|เคย|เกิด|ขึ้น|มา|ก่อน| |ทั่ว|โลก|ก็|ยัง|ไม่|พบ|เชื้อ| |H|5|N|1| |เป็น|เฉพาะ|ใน|สัตว์|ปีก| |เพิ่ง|ระบาด|สู่|คน| |เมื่อ|ต้น|ปี|ที่|ผ่าน|มา| |ส่วน|ของ|ไทย|มี|ผู้|ป่วย|ตั้งแต่|ต้น|ปี| |2546| |ยืนยัน|ว่า|มี|ผู้|ติด|เชื้อ|ไข้|หวัด|นก|เพียง| |13| |คน| |เสีย|ชีวิต| |9| |ราย| |ส่วน|ปี|นี้|ติด|เชื้อ|เพียง|ราย|เดียว|และ|เสีย|ชีวิต|ไป|แล้ว',
#  'ที่| |จ.ปราจีนบุรี| |ข้อมูล|การ|แพร่|ระบาด|จาก|คน|สู่|คน| |ยัง|ไม่|มี|รักษาการ|ปลัด|กระทรวงสาธารณสุข|กล่าว|ด้วย|ว่า| |อย่าง|ไร|ก็ตาม| |ใน|กรณี|ของ| |จ.กำแพงเพชร| |เป็น|กรณี|ศึกษา|ที่|น่า|สนใจ| |แต่|ยัง|ไม่|ยืนยัน|ว่า|เป็น|ไข้|ขณะ|นี้|ได้|ส่ง|ชิ้นส่วน|ไป|ตรวจสอบ|อยู่| |โดย|ผู้|ป่วย|ที่|อยู่|ใกล้ชิด|กับ|ผู้|ตาย| |เพราะ|อยู่|บ้าน|เดียว|กัน| |จะ|เป็น|กุญแจ|ดอก|สำคัญ| |มี|การ|ส่ง|ตัวอย่าง|ไป|ตรวจ|พิสูจน์|เพิ่มเติม|แล้ว| |มั่นใจ|ว่า|เชื้อ|ไข้|หวัด|นก|คง|ไม่|ระบาด|ง่าย|ๆ| |อย่าง|ที่|ระแวง|กัน| |แต่|ก็|เป็น|เรื่อง|ที่|น่า|สนใจ| |ส่วน|กรณี|ที่| |พ.ต.ท.ทักษิณ ชินวัตร| |นายก|รัฐมนตรี| |ไม่|พอใจ|การ|ทำ|งาน|ของ|เจ้าหน้าที่|ที่|เกี่ยวข้อง|นั้น| |น.พ.จรัล|กล่าว|ว่า| |นายก|ฯ| |กำชับ|ให้|รีบ|ลง|มา|ดูแล|และ|ควบคุม|พื้นที่|ระบาด|ให้|ได้|ทั้ง|ใน|คน|และ',
#  'ทาง|ด้าน|นายกมล เจริญเกษ| |ปศุสัตว์|กำแพงเพชร| |เผย|ว่า| |ขณะ|นี้|ทาง|จังหวัด|ไม่|ต้อง|ประกาศ|เป็น|พื้นที่|สี|แดง| |แต่|ทั้ง|จังหวัด|เป็น|พื้นที่|ต้อง|สงสัย| |ดัง|นั้น| |เจ้าหน้าที่|ปศุสัตว์|สามารถ|เข้า|ทำลาย|สัตว์|ปีก| |ได้|ทุก|พื้นที่| |ถ้า|เกิด|สงสัย|ว่า|ใน|พื้นที่|ใด|มี|สัตว์|ปีก|ป่วย|ตาย| |ซึ่ง|อาจ|ติด|เชื้อ|ไข้|หวัด|นก|ที่|กำลัง|ระบาด|หนัก|อยู่|ใน|ขณะ|นี้',
#  'หนังสือพิมพ์|ไทยรัฐ| |ปี|ที่| |55| |ฉบับ|ที่| |17052| |9|/|28|/|2004',
#  'ตรวจ|แนว|รบ|อาหาร|ปลอด|ภัย| |หลัง|ผ่าน|วิกฤต| |"|ไข้|หวัด|นก|"',
#  'อาหาร|ถือ|เป็น|สิ่ง|ที่|จำเป็น|ต่อ|มนุษย์| |และ|อาหาร|ที่|ปลอด|ภัย|เท่า|นั้น|จึง|จะ|ให้|คุณค่า|ต่อ|ร่างกาย| |เพื่อ|ให้|ผู้|บริโภค|ได้|รับ|อาหาร|ที่|ปลอด|ภัย| |จึง|ต้อง|มี|ระบบ|ดูแล|ควบคุม|และ|ตรวจสอบ|คุณภาพ|ทุก|ขั้นตอน| |ด้วยเหตุนี้|รัฐบาล|จึง|ประกาศ|ให้|ปี| |2547| |เป็น|ปี|อาหาร|ปลอด|ภัย',
#  'นโยบาย|ดัง|กล่าว| |แรก|ๆ| |ทำท่า|ว่า|จะ|ไป|ได้|ดี| |เพราะ|หน่วยงาน|ที่|เกี่ยวข้อง|อย่าง| |กระทรวงเกษตรฯ| |และ|กระทรวงสาธารณสุข| |(|สธ.|)| |ได้|เร่ง|ดำเนิน|การ|ให้|เป็น|รูปธรรม| |แต่|เมื่อ|เกิด|วิกฤตการณ์|ไข้|หวัด|นก| |นโยบาย|นี้|ถึง|กับ|ออก|อาการ|เซ']

# %%
train_word_count
# Out:
# 1042797

# %%
train_vocabulary
# Out:
# {'',
#  'ซอยมังกร',
#  'ก้าวร้าว',
#  'ประจำใจ',
#  'นายรองพล เจริญพันธ์',
#  'ต.ปากแคว',
#  'สุก',
#  'ซอยพหลโยธิน 52',
#  'นายอภิสิทธิ์เวชชาชีวะ',
#  'พ.ต.ต.ชาตรี',
#  'พระโอรส',
#  'กรมคุมประพฤติ',
#  'โจษขาน',
#  'ปราบปรามการกระทำผิดต่อเด็ก เยาวชน และสตรี',
#  'บูฆอรี นิ้วหลี',
#  'นายจิตรพงษ์ กว้างสุขสถิตย์',
#  'ปวด',
#  'สภอ.สตึก',
#  'หม่อมหลวง',
#  'ชอบใจ',
#  'หน้าแตก',
#  'กัมป์ ไอเนส',
#  'เมืองพัทยา',
#  'อุทยานแห่งชาติเขาใหญ่',
#  'บ้านทุ่งยามู',
#  'มูลฟ้อง',
#  'ป.ป.ช./NE>',
#  'นายวิเชียร โคตรเอื้อม',
#  'พี่น้อง',
#  'โรงพยาบาลสมเด็จพระสังฆราช',
#  'บริษัทท่าอากาศยานไทยจำกัด(มหาชน',
#  'แจ็กเก็ต',
#  'รับผิดชอบ',
#  'เข้มงวด',
#  'นายพิจิตต รัตตกุล',
#  '481',
#  'นายสุทิน เจริญรักษา',
#  'กระทรวงคมนาคม',
#  '6438',
#  'นายวิโรจน์ แก้วพิทยา',
#  'ลาง',
#  'สุ่ม',
#  'บริษัท ไอทีวี จำกัด(มหาชน)',
#  'ไอเอ็นเอ็น',
#  'นายอุกฤษฎ์ถาวรไกรกุล',
#  'วัดราษฏร์สโมสร',
#  'นายเจษฎา จันทร์ดี',
#  'พ.ต.อ.มาโนช',
#  'ทรัพยากรธรรมชาติฯ',
#  'รพ.ภูมิพลอดุลยเดช',
#  'ก.พ.',
#  'เว็บบอร์ด',
#  'ลาดหลุมแก้ว',
#  'ศูนย์ปฏิบัติการตำรวจส่วนหน้า',
#  'กองวินัย',
#  'นางเฉิง',
#  'เซรุ่ม',
#  'พล.ร.อ.สุรินทร์ เริงอารมณ์',
#  'นายสาทิตย์ชัย',
#  'ด.ช.นิติกร ชิตนอก',
#  'น.พ.ไพศาล',
#  'ร้านดังกิ้นโดนัท สยามสแควร์',
#  'เวทีมวยราชดำเนิน',
#  'ครอบครอง',
#  'แคระ',
#  'นายประทีป ปิติสันต์',
#  'ทำเนียบเครมลิน',
#  'รศ.วิริยะ นามศิริพงศ์พันธุ์',
#  'เปิบ',
#  'ต.หนองสาหร่าย',
#  'ครูทอง',
#  '2248',
#  'แคนดิเดต',
#  'นายโจเซฟ บิเดน',
#  'นายเสรี หวังในธรรม',
#  'สุนทรพจน์',
#  'นายเมฆินทร์ เมธาวิกูล',
#  'พะเยา',
#  'สถานีข่าวธุรกิจฟอกซ์บิสซิเนสเน็ตเวิร์ค',
#  '401',
#  'นายประเสริฐ ทองเจริญ',
#  'ศูนย์การแพทย์โรงพยาบาลกรุงเทพ',
#  'พลเอกสนธิ',
#  'คลุกคลี',
#  'กวน',
#  'ผลัก',
#  'ซิสเต็ม',
#  'แซม',
#  'ลบล้าง',
#  'อาคารเทคโนโลยีสารสนเทศ',
#  'ง่อนแง่น',
#  'มิ.ย.',
#  'วัดสัจจธรรมาราม',
#  'ปลากราย',
#  '16828',
#  'ยอม',
#  'เข็ด',
#  'บริษัทไทยเดินเรือทะเล',
#  'ราคะ',
#  'มันนี',
#  'การกระทรวงอุตสาหกรรม',
#  'ราชอาณาจักร',
#  'พระชนม์',
#  'มหานคร',
#  'แต่',
#  'นายประกาศิต',
#  'เมืองคอน',
#  'สคอวช์',
#  'นายธีรศักดิ์',
#  'นายชัย สุวพันธุ์',
#  'บิ๊กไบค์',
#  'เรือนจำปากพนัง',
#  'เทนนิส',
#  'กระจ่างแจ้ง',
#  'ถนนวิทยุ',
#  'ตีสนิท',
#  'นายยงยุทธ วีระพงศ์',
#  'บริสุทธิ์ใจ',
#  'สภาเทศบาลเมืองสุไหงโกลก',
#  'แอคคอร์ด',
#  'ยุ่งเหยิง',
#  'ตีนแมว',
#  'เดเอฟเบ',
#  'ปิยะพันธ์ จัมปาสุต',
#  'พุทธมณฑลสาย 2',
#  'ซิมบับเว',
#  'อนุกรรมธิการ',
#  'สนเท่ห์',
#  'เมท',
#  'สปก.',
#  'ภัยมืด',
#  'สถาบันส่งเสริมการสอนวิทยาศาสตร์และเทคโนโลยี',
#  'Charlie',
#  'พิพัฒน์',
#  'เส้นตาย',
#  'คลองนครเนื่องเขต',
#  'ตกผลึก',
#  'นายอดัม เออร์วิน วันสเลย์',
#  'ได้เปรียบ',
#  'หัวอก',
#  'ปชต.',
#  'นายบุญเสริม จินเจนสุวรรณ',
#  'คุณหญิงพจมาน',
#  'คุณหญิงกษมา',
#  'คุณสรรเสริญ วงศ์ชะอุ่ม',
#  'ซิ หยาน',
#  'ไมโครพลาสมา',
#  'จี๊ด',
#  'ร่มรื่นแมนชั่น',
#  'ทองก้อน',
#  'แม่ค้า',
#  'ซัก',
#  'มวล',
#  'ยั้ง',
#  'เคารพบูชา',
#  'นิติบุคคล',
#  'ทีม SRRT',
#  'อากัปกิริยา',
#  'นพ.เฉลิม ศักดิ์สรชัย',
#  'พิจารณา',
#  'เซนติเกรด',
#  'ผศ.ดร.บัวพันธ์ พรหมพักพิง',
#  'บุคคลธรรมดา',
#  'ห้างเซ็นทรัลเวิลด์',
#  'คละเคล้า',
#  '478',
#  'พม่า',
#  'บริษัทประมงไทย(สงขลา)จำกัด',
#  'คณิต ณ นคร',
#  'เบื่อ',
#  'แกรนด์แคนยอน',
#  'ประเทศเยอรมัน',
#  'มหาวิทยาลัยเชียงใหม่',
#  'แม่',
#  'พล.ต.ต.ประวิทย์ ศิลปสุวรรณ',
#  'สุทธิ',
#  'ภ.จว.ยโสธร',
#  'กลุ่มเมาโร',
#  'ยักยอก',
#  'นายสรอรรถ กลิ่นประทุม',
#  '40',
#  'แล้วยัง',
#  'พ.ต.อ.วิทยา ประยงค์พันธุ์',
#  'จ.แม่ฮ่องสอน',
#  'นายสมาน',
#  'ต.สองแพรก',
#  'กระบี่',
#  '293',
#  'ถอย',
#  'บก.ปศท.',
#  'พล.ท.สำเริง ศิวาดำรงค์',
#  'นางสายชล',
#  'จำพวก',
#  'กรมการกำลังสำรอง',
#  'สภ.อ.ยะหา',
#  'กาลเทศะ',
#  'พรู',
#  'ชนบท',
#  'บ้านลีซอ',
#  'ฉับไว',
#  'อนาถา',
#  'พิเชษฐ',
#  'นายกิตติศักดิ์ ประทุม',
#  'มโนราห์',
#  'วัดหาดใหญ่ใน',
#  'สำนักงานอัยการพิเศษฝ่ายคดีภาษีอากร 4',
#  'จั่น',
#  'สภ.อ.เมืองยะลา',
#  'ฉ้อโกง',
#  'โครงการทูบีนัมเบอร์วัน',
#  'ปกเกล้าปกกระหม่อม',
#  'ชมรมอาสาสมัครป้องกันความปลอดภัยรักษาการนายกฯ',
#  'ไอซ์',
#  'นายพรพินิจ พรประภา',
#  'นายธนพร ศรียากูล',
#  'วัดเหนือเขมราฐ',
#  'เขตเทศบาลเมืองสะเดา',
#  'วายพีดี',
#  'สมเด็จพระนางเจ้าฯ',
#  'ฮอลลีวู้ด',
#  'กองบังคับการตำรวจจราจร',
#  '1934',
#  'เวฟ',
#  'FIT',
#  'บรรณวิทย์"',
#  'เพลย์บอย',
#  'วัดเขตอุดมศักดิ์',
#  'ส.ต.ต.ปัญจะ สามิภักดิ์',
#  'นับหน้าถือตา',
#  'น้องกัปตัน',
#  'พระครูสิทธิธรรมวิภัช',
#  'อำลา',
#  'ข้าพระพุทธเจ้า',
#  '604',
#  'อ.บางสะพาน',
#  'เป่าจินจง',
#  'อิน',
#  'กระชั้นชิด',
#  'พล.ต.ท.ภาณุพงศ์สิงหราณอยุธยา',
#  'ก็ได้',
#  'พ.ต.ท.อุดร',
#  'เขี่ย',
#  'เช้ามืด',
#  'นายสุรเกียรติ์',
#  'นายวิลเลียม ไลล์มอนซัน',
#  'สำนักวิทยาศาสตร์',
#  'ต.ราชาเทวะ',
#  'เคารพนับถือ',
#  '918',
#  'นายเปรม',
#  'สมาชิกสภานิติบัญญัติแห่งชาติ',
#  'นายยง จันทรังสี',
#  'นายนรินทร์สหสาย',
#  'กลับตัว',
#  'หมายเหตุ',
#  'หมู่บ้านหม่หลุ',
#  'ครัว',
#  'แขวงดุสิต',
#  'กองบิน 56',
#  'ทีม "หงส์แดง',
#  'ปราศัย',
#  'นายโกสินทร์ สีดา',
#  'ต.นาจอมเทียน',
#  'นายวอร์เร็น บัฟเฟตต์',
#  'มาย',
#  'องค์การการประชุมอิสลาม',
#  'เผาผลาญ',
#  'พลูโตเนียม',
#  'เจ้ามือ',
#  'ยีน',
#  'ขอบข่าย',
#  'วินสตันเชอร์ชิล',
#  'อ.เจาะไอร้อง',
#  'คณะกรรมการ บมจ. อสมท.',
#  'ซื่อตรง',
#  'ศาลจังหวัดขอนแก่น',
#  '222',
#  'สุจินดา',
#  'กัดฟัน',
#  'สะกด',
#  'พ.ต.อ.ณรงค์วิทย์ พ่วงเภตรา',
#  'กลุ่มนครพนม',
#  'โอเล็กไซ เบลิค',
#  'สนามกีฬากลางค่ายสุรนารี',
#  'ติดใจ',
#  'หวด',
#  'ต.ปอพาน',
#  'หนักแน่น',
#  'ทุกข์ทรมาน',
#  'รัฐ',
#  'ป้วนเปี้ยน',
#  'ดอนเมือง',
#  'โซนร้อน',
#  'ล้อม',
#  'โลว์ไรเดอร์',
#  'ปริญญา',
#  'ละเว้น',
#  'ฝ่ายคดีอาญา',
#  'ทัณฑสถานวัยหนุ่ม จ.นครศรีธรรมราช',
#  'เซนาดอร์ กามาร่า',
#  'ธีรยุทธ',
#  'นายวิบูลย์ เข็มเฉลิม',
#  'พ.อ.ดร.นาฬิกอติภัค',
#  'เอาใจ',
#  'เปิดใจ',
#  'ห้างสยามพารากอน',
#  'ปัญญาชน',
#  'อ.สีคิ้ว',
#  'บริษัทไทยเพรซิเดนท์ฟูดส์ จำกัด(มหาชน',
#  'ข้อมูล',
#  'Second',
#  'มหาดไทย',
#  'นายกล้านรงค์ จันทิก',
#  'สตั๊ด',
#  'นางทองอยู่',
#  'อพวช.',
#  'นายจำลอง ภู่พัฒน์',
#  'นางเมลินดา เกตส์',
#  'อบจ.พัทลุง',
#  'นายเผือด หอมชื่น',
#  'ด.ช.คงดนัย ประไพ',
#  'น.ส.ขวัญตา ผลไม้',
#  'น้ำชี',
#  'นายบวรศักดิ์ อุวรรโณ',
#  'อดทนอดกลั้น',
#  '0361',
#  'นายเอลิสซีฟ',
#  'พัน.',
#  '16807',
#  'ธิดา',
#  '269',
#  'ทะนง',
#  'เหลือง',
#  'บ่ง',
#  'ยาไส้',
#  'นายสังศิต พิริยะรังสรรค์',
#  '678',
#  'พ.ต.อ.พงษ์เดช ชัยตวัฒน์',
#  'ร่ำรวย',
#  'ต.หนองเอี่ยน',
#  'นางสาวนพมาศ นวลเพชร',
#  'กะเหรี่ยง',
#  'โยม',
#  'กลยุทธ์',
#  'สามารถ',
#  'คอร์รับชั่น',
#  'อุบลฯ',
#  'เดช',
#  'จังหวัดกระบี่',
#  'โคลเซ',
#  'นายปรีชา บุตรศรี',
#  'เก๊',
#  'เชื่อม',
#  'พี่น้องประชาชน',
#  'ที่แล้ว',
#  'กระเปาะ',
#  'serrations',
#  'เกรย์วูล์ฟ',
#  'อ.สัตหีบ',
#  'โคโล ตูเร',
#  'กองทัพภาคที 3',
#  'มทบ.33',
#  'พลเอกหม่อง เอ',
#  '4547',
#  'บ้านบาเล๊ะ',
#  'พ.ต.อ.พินิจ',
#  'นางนิตยา มาศะวิสุทธิ์',
#  'หาดใหญ่',
#  'แทง',
#  'พล.อ.ปฐมพงษ์ เกษรศุกร์',
#  'อุปทาน',
#  'บธ',
#  'สำนักงานคณะรัฐมนตรี',
#  'สำนักงานพัฒนาเกษตรเขตที่ 1',
#  'สรรหา',
#  'กบฏเชเชน',
#  'บ้านห้วยโปร่ง',
#  '!!!',
#  'ร.ต.ท.มาชา แก้วทอง',
#  'ฮอลแลนด์',
#  'ธรรมาภิบาล',
#  'นางปริศนา กล่ำพินิจ',
#  'พ.ต.ท.ทักษิณ ชินวัตร',
#  'พ.ต.อ.สุปรีชา อุณหนันท์',
#  'นางเกศิณี ทิมเทพ',
#  'พ.อ.อัคร ทิพย์โรจน์',
#  'กรมสอบสวนคดีพิเศษฯ',
#  'คนใหญ่คนโต',
#  'ซอยจรัญฯ 35',
#  'นายวัฒน์',
#  'นายเก่ง',
#  'ทรท.',
#  'มรภ.จันทร์เกษม',
#  'จนเกินไป',
#  'ช่วงเกียว',
#  '06',
#  '7771496',
#  'อาหารการกิน',
#  'ร่อง',
#  'ภ.1',
#  'หม้อน้ำ',
#  'นายปราโมทย์ พิพัฒน',
#  'วัดทวีการะอนันต์',
#  'หอนิทรรศการศิลปและวัฒนธรรม',
#  'ปลื้มปิติ',
#  'สิบ',
#  'ด.ญ.ฟิรดาวสาหะ',
#  'นายประสิทธิ์ ปทุมารักษ์',
#  'พัดพา',
#  'แสตมป์',
#  '545',
#  'นางสุกันญา ศิริสาร',
#  'อ.พุนพิน',
#  'กองกำลังเฮซบุลเลาะห์',
#  'นายปิยธวัชตุ่มมะ',
#  'จังหวัดพัทลุง',
#  'นายบรรหาร',
#  'คลองรังสิต ประยูรศักดิ์',
#  'ธพว.',
#  'อาคาร',
#  'อับดุลลาห์ อาหมัด บาดาวี',
#  'ศฉ',
#  'ต.พังตรุ',
#  'ดร.นพดล กรรณิกา',
#  'กองพันทหารม้าที่ 10',
#  'นายมามะ เจ๊ะสือแม',
#  'นายศุภชัย กฤตผลชัย',
#  'สมาคมนักข่าววิทยุและโทรทัศน์ไทย',
#  'ไมกาห์ ริชาร์ดส',
#  'ยามาฮ่า',
#  'กิตติมศักดิ์',
#  'สมาคมกู้ภัยจังหวัดอ่างทอง',
#  'นิติธรรม',
#  'กองพันทหารม้าที่ 9',
#  'สมอ.',
#  'ลำคลองแม่ลา',
#  'ลอนดอน',
#  'เข้าที่',
#  'คณะพาณิชยศาสตร์และการบัญชี',
#  'องค์การอนามัยโลก เขตแปซิฟิกตะวันตก',
#  'นายวิเชษฐ์ มุสิกรังษี',
#  'เศรษฐี',
#  'จังหวัดพิจิตร',
#  'ตะนอย',
#  'กรุงโรม',
#  'เพาะเลี้ยง',
#  'คลองสิบสี่',
#  'นายสถิตย์ สระแก้ว',
#  'ทล.',
#  'สเตอรอยด์',
#  'นายอภิเชาว์ สีลวานิช',
#  'นายพุทธิพงษ์ ปุณณกันต์',
#  'เขาสามมุก',
#  'รอบคอบ',
#  'เทิดทูน',
#  'ลูกตา',
#  'นางเคลือวัลย์',
#  'อำเภอโพธิ์ประทับช้าง',
#  'จังหวัดตราด',
#  'วอล์กเอาท์',
#  'พ.ต.ท.ญาณวุฒิ',
#  'ถ่ายเอกสาร',
#  'นายอำนวย ธันธรา',
#  'นายสุวรรณ กู้สุจริตกุล',
#  'โรงพยาบาลอ่างทอง',
#  'นฐ',
#  'ร้องขอ',
#  'เสียหาย',
#  'แม่น้ำลพบุรี',
#  'มัชฌิมาธิปไตย',
#  'กองบัญชาการ มณฑลทหารบกที่ 24',
#  'คู่บ้านคู่เมือง',
#  'บ้านเผ่าไทย',
#  'นายสุธี',
#  'นายจารึก เฮงรัศมี',
#  'มหาเถระ',
#  'ลาก',
#  'ปัญญา',
#  'พระครูภาวนาวรานุศาสก์',
#  'เม็ดเลือด',
#  'หมู่บ้านศิริเกษม 1',
#  'น.ส.ศุภลักณ์ จูจีน',
#  'มิด',
#  'นกเป็ดน้ำ',
#  'หวั่นวิตก',
#  'อ.โนนสัง',
#  'แต่ละ',
#  'หัวกะโหลก',
#  'นายสมพงษ์ เชาว์วัลแล่น',
#  'นายอำนาจ มุทิตาเจริญ',
#  'เวสต์แฮม',
#  'วัดเบญพาด',
#  'สำนักงานสหประชาชาติ',
#  'ชะตากรรม',
#  'ชาติไทย',
#  'สำนักคุ้มครองพระพุทธศาสนา',
#  'บก.น.1',
#  'จีพีโอ',
#  'สโลวีเนีย',
#  'แขวง',
#  'opinion',
#  'หอการค้า จ.เชียงใหม่',
#  'ทุกขลาภ',
#  '314',
#  'อ.สนามชัย',
#  'บริษัท เวิร์คพอยท์ เอ็นเทอร์เทนเมนท์ จำกัด(มหาชน)',
#  'กรมบัญชีกลาง',
#  'ขนถ่าย',
#  'บษ',
#  'ด้อย',
#  'แมลงเบ้ากุดจี่ยักษ์',
#  'พ.ต.ท.อาคม',
#  'คณะกรรมการสลากฯ',
#  'อวอร์ดส',
#  'ต.หนองกี่',
#  'นายจตุพร',
#  'กุด',
#  'พระธรรมคุณาภรณ์',
#  'นนทบุรี',
#  'นายวราวุธ ศิลปอาชา',
#  'ลูกหนัง',
#  'เจ้าชายจิกมี',
#  'ทับ',
#  'สำนักงานอัยการเขต 2',
#  'หมักหมม',
#  'บางปลาม้า',
#  'นายธวัช เพชรวิระ',
#  'ยังคง',
#  'ฐาน',
#  'สำนักงานคดีปกครองนครราชสีมา',
#  'สำนักงานตำรวจสกอตแลนยาร์ด',
#  'นายเอม',
#  'เคเบิลทีวี',
#  'พบเห็น',
#  'เธอ',
#  'ปิดตัว',
#  'แก้วตา',
#  'เซนเซอร์',
#  'เทอร์รี',
#  'จังหวัดชุมพร',
#  'น.ส.ศศมน',
#  'ทิม โบรอฟสกี้',
#  'โบราณวัตถุ',
#  'นายจรัล ภักดีธนากุล',
#  'ด.ญ.สาว',
#  'นายซัมรี',
#  'แพร่ระบาด',
#  'นายจุมพล ณ สงขลา',
#  'หลา',
#  'คลองชมพู',
#  'แจ้ง',
#  'โหมด',
#  '851',
#  'สูงสุด',
#  'นายสนอง เครือมาก',
#  'นายหน้า',
#  'ฉีกขาด',
#  'วงจร',
#  'พ.ต.ท.ภูมินทร์',
#  'พ.ต.อ.เรวัช กลิ่นเกษร',
#  'ซีพีเอฟ.',
#  'ขึ้นง',
#  'ทูลกระหม่อม',
#  'ชุมชนแสงจาระ',
#  'ร.ต.วิจิตรอยู่สุภาพ',
#  'กลุ่มประชาชนผู้รักประชาธิปไตย',
#  'คันนายาว',
#  'อุจจาระ',
#  'กลุ่ม 24 มิถุนาประชาธิปไตย',
#  'น้องฝ้าย',
#  'กรมศิลปากร',
#  'สหราชอาณาจักร',
#  'นายฟัดรุดดีน',
#  'รมย์ จียะยันต์',
#  'บางแสน',
#  'โควต้า',
#  'นายรุ่งฤทธิ์',
#  'ร.ต.ท.วรุต กิตยานุกุล',
#  'นายคริสเตียน',
#  'นายเสรี สุวรรณภานนท์',
#  'ชุมชนตลาดบางใหญ่เก่า',
#  'มะรุมมะตุ้ม',
#  'พระราชกฤษฎีกา',
#  'นายบัน คี มุน',
#  'พล.อ.สะพรั่ง กัลยาณมิตร',
#  'คณะปฎิรูปฯ',
#  'ปั้มเจ็ท',
#  'ด.ช.วิรัตน์',
#  'คณะกรรมการสภาการหนังสือพิมพ์แห่งชาติ',
#  'โอลด์แทรฟฟอร์ด',
#  'ภาค',
#  'นายประสิทธิ์ ตั้งศรีเกียรติกุล',
#  'น.ส.นิด',
#  'จินตนาการ',
#  'บ้านเดวิด',
#  'พล.อ.ไตรรงค์ อินทรทัต',
#  'นับ',
#  'รางวัล',
#  'ดรีมทีม',
#  'แจ่มใส',
#  'ต.บ้านกลาง',
#  'ชมรมสถาบันศึกษาปอเนาะ 5 จังหวัดชายแดนภาคใต้',
#  'นายประสาน สุขรังสรรค์',
#  'นายพุทธิพงษ์',
#  'นายสุเมธ ชัยเลิศวานิชกุล',
#  'อุทยานแห่งชาติแก่งกรุง',
#  'ตลาดหุ้นวอลล์สตรีท',
#  'พ.ต.ต.ไวยกูล',
#  'สวนสัตว์เชียงใหม่',
#  'เหนื่อยล้า',
#  'นายสมบูรณ์ อัตตนาถ',
#  'MIGUELANGELGAMELOSUNA',
#  'น.พ.เดวิด อาร์ นาลิน',
#  'แผลง',
#  'สำนักคดีอาญาพิเศษ',
#  'ครรภ์',
#  'ตำรวจสันติบาล',
#  'นายวันชัย สร้อยทอง',
#  'ถนนหลักเมือง',
#  'บรรเลง',
#  'โรงพยาบาลสุราษฎร์ธานี',
#  'รร.สีมาธานี',
#  'คลาด',
#  'กุหลาบ',
#  'บริษัทเดินเรือทะเล',
#  '527',
#  'สื่อ',
#  'สภ.อ.เมืองนราธิวาส',
#  'เณร',
#  'นายปิยพันธุ์ นิมมานเหมินท์',
#  'พ็อกเกต',
#  'ปั๊บ โปเตโต้',
#  'น้องบี',
#  'บ้านห้วยทราย',
#  'ฮาวาย',
#  'พ.ท.มนัส',
#  'พ.ต.ท.นพ.พิสิฐ ธรรมสุริยะ',
#  'พล.ท.องค์กรทองประสม',
#  'กองกำกับการสืบสวนสอบสวนนครบาล7',
#  'ผช.',
#  'ฤๅษีภาระตะ',
#  'อินดอร์',
#  'พระอัครศาสนูปถัมภก',
#  'ห้างคาร์ฟูร์',
#  'รัฐศาสตร์ จุฬาฯ',
#  'ชิลี',
#  'คอม',
#  'นิโก้ โควัช',
#  'นครพนม',
#  'รามัลเลาะห์',
#  'หลบ',
#  'ไหปลาร้า',
#  'ประสม',
#  'ร.ท.',
#  'อ่อนโยน',
#  'เวย์',
#  'ออสเตรเลียไฟแนนเชียล รีวิว',
#  'น้ำพริก',
#  'โล่',
#  'คาดหวัง',
#  'รัฐกะฉิ่น',
#  'ฟุตซอล',
#  'กัมบารี',
#  'มานะ',
#  'สำนักงานพระพุทธศาสนาแห่งชาติ',
#  'พล.อ.ธรรมรักษ์ อิศรางกูล ณ อยุธยา',
#  'นางสาว',
#  'สัจธรรม',
#  'จังหวัดปราจีนบุรี',
#  'ผิดสังเกต',
#  'สนง.สาธารณสุขจังหวัด',
#  'ร่วมมือร่วมใจ',
#  'นายโอซามา บิน ลาเดน',
#  'ฮัมวี่',
#  'นายแก้วสรร',
#  'อาฆาตมาดร้าย',
#  'พ.ต.ท.วิทวัส ทัศนศร',
#  'คูคลอง',
#  'พ.ต.อ.สมศักดิ์ จิตติรัตน์',
#  'หัวนม',
#  'อิระวดี',
#  'ครูหยุย',
#  'สตีวี่ จ',
#  'นายนิรุต',
#  'พันโทแกรี เค้ก',
#  'ตึกชินวัตร',
#  'บก.ภ.จว.สงขลา',
#  '876',
#  'แจง',
#  'นายศิษฐา วงศ์สุเมธ',
#  'แขวงอนุสาวรีย์',
#  'อ.ทัพทัน',
#  'ซู',
#  'ฆาต',
#  'กุมภาพันธ์',
#  'พ.ต.อ.ฉัตรไชย เรือนเมฆ',
#  'ต.ทาปลาดุก',
#  'ต.ปาเสมัส',
#  'ค่ายพระยอดเมืองขวาง',
#  'แม็ก',
#  'ห่า',
#  'สำนักงานกรรมการการเลือกตั้งจังหวัดสมุทรปราการ',
#  'SRRT',
#  'นายมูฮัมหมัด อัลลูไวรี',
#  'สมเด็จพระราชินี',
#  'เมืองน่าน',
#  'นครสวรรค์นั้น',
#  'หมู่บ้านภัทรนิเวศน์',
#  'บ้านท่ามะเกว๋น',
#  'ต้อน',
#  'คณะกรรมการสิ่งแวดล้อมแห่งชาติ',
#  'ดูซิ',
#  'ร.ต.ท.',
#  'Digital TK park',
#  'รพ.จุฬาฯ',
#  'ขาดกัน',
#  'พระราชสุธรรมมภรณ์',
#  '501',
#  'ต.สะเตงนอก',
#  'สนุกเกอร์',
#  'พลทหารเชาวนิต จันทะสิน',
#  'เทศบาลเมืองบุรีรัมย์',
#  'พล.ต.อ วาสนา',
#  'รพ.สมเด็จเจ้าพระยา',
#  'น.ส.สุวรรรี ไชย มงคล',
#  'นายร่อแห็ม เกมบุตร',
#  'นายธวัชชัย เทอดเผ่าไทย',
#  'โรงแรม เจ.บี.',
#  'นายพูนสวัสดิ์ นาทองคำ',
#  'กฎระเบียบ',
#  'คณะกรรมการรณรงค์เพื่อการปฏิรูปสื่อ',
#  'เจ้าคุณ',
#  'เอ็ดวิน เตโนริโอ',
#  'นายชินวรณ์ บุณยเกียรติ',
#  'โรงพยาบาลราษฎร์ยินดี',
#  'ประธานาธิบดี"บิล คลินตัน"',
#  'งั้น',
#  'นายสุเมธอุปนิสากร',
#  'โน้มน้าว',
#  'สืบสวนสอบสวน',
#  'นางสินนาถ',
#  'เสือเหลือง',
#  'ดาวิด แฟร์เรร์',
#  'ตัน',
#  'นายลีจอง วอค',
#  'ธูป',
#  'ธรณี',
#  'ถอดสี',
#  'นายคอสตา',
#  'ตำรวจปฏิบัติการพิเศษ(191)',
#  'หอพักสตรีนิศารัตน์',
#  '328',
#  'พล.ต.ต.ปัญญา',
#  'ล้มกระดาน',
#  'น.ส.ลภัสรดร เอกชน',
#  'ดรีมไลน์เนอร์',
#  'ย่างกุ้ง',
#  'โอกาส',
#  'เดลินิวส์',
#  'ต.บูกิต',
#  'คลุก',
#  'นายฐิตินันท์ พงษ์สุทธิรักษ์',
#  'รอยัล กอล์ฟ',
#  'บุคลาการ',
#  'แยกมิสกวัน',
#  'นายนิวท์ กริงกิช',
#  'เชสเตอร์กริล',
#  'Hearts',
#  'ชินานาฎ',
#  '410',
#  'น้อง เดียว',
#  'ย่อยสลาย',
#  'อำเภอหาดใหญ่',
#  'ภาษีอากร',
#  'จดทะเบียน',
#  'น.พ.สันต์ หัตถีรัตน์',
#  'รับขวัญ',
#  'นายศิริศักดิ์ ติยะพรรณ',
#  'พระสุวรรณ ฐานาคโร',
#  'นายลำดวน คะนึงคิด',
#  'สเตรทไทมส์',
#  'แจ๊ส',
#  'กองพลทหารราบที่ 9',
#  'ชีคมุสซาฟาร์ ซูคอร์',
#  'เขียวขี้ม้า',
#  'นายวุฒิกร สุริยะฉันทนานนท์',
#  'หลับนอน',
#  'อนุสัญญา',
#  'เพศ',
#  '994',
#  'มุม',
#  'หาดพัทยา',
#  'สื่อสาร',
#  'นายศานติ ประสาทกุล',
#  'ถนนสายรามัน',
#  'อ.จะนะ',
#  'ดำรง',
#  'วัดสัมพันธวงศ์',
#  'พระตำหนักทักษิณราชนิเวศน์',
#  'ต.คลองนิยมยาตรา',
#  'ผ่อนปรน',
#  'เอี้ยว',
#  'นายจุฑาธวัช',
#  'ต.โคกหม้อ',
#  'ประหลาดใจ',
#  'นายวิเชียร ปิยะวรากร',
#  'เว็บมาสเตอร์',
#  'นายภีระพล',
#  'ศูนย์วิจัยเอแบคนวัตกรรมทางสังคม',
#  'อ.เชียงม่วน',
#  'จว.ตาก',
#  'รศ. น.พ. กริช',
#  'แพลนเน็ต',
#  'สถานีหนองหล่ม',
#  'อาพาธ',
#  'แอร์เอเชีย',
#  'กองงานส่วนพระองค์',
#  'นาง อรุณี ทองพรม',
#  'พรรคคอมมิวนิสต์',
#  '160',
#  'หัวแม่มือ',
#  'ตามใจ',
#  'ปอนด์',
#  'อังเดร ปิร์โล',
#  'นางทุเรียน รุ่งเรือง',
#  'นายบวรศักดิ์',
#  'จว.',
#  'เกาหลี',
#  'นายเสวก',
#  'ดร. พิจิตต รัตตกุล',
#  'เครือข่าย19กันยา',
#  'อ.แสวงหา',
#  'ทัศนะ',
#  'อลูมิเนียม',
#  'เข็ม',
#  'ตัวเมือง',
#  'น้องโด่ง',
#  'เพื่อให้',
#  'นายยงยุทธ',
#  'มณฑลทหารบกที่ 21',
#  'สำนักงานอัยการพิเศษฝ่ายคุ้มครองสิทธิและช่วยเหลือทางกฎหมายเขต 1',
#  'ทันใด',
#  'โรงเรียนบ้านเจาะบันตัง',
#  'พ.ญ.คุณหญิงพรทิพย์ โรจนสุนันท์',
#  'เรียบร้อย',
#  'ส.ข.',
#  'พ.ต.ท.วัชรินทร์ ประสพดี',
#  'ตื้ม',
#  '140',
#  'ท่าอากาศยานสุวรรณภุมิ',
#  'อ.เทพา',
#  'ฝีก',
#  'พระครูปลัดธรราคี จะธาตุสี่พุทธครุฑนาคเสโน',
#  'อีโต้',
#  'เจ้าพระยา',
#  'การท่าเรือ',
#  'ธนาคารธกส.',
#  '524',
#  'ทะเลจีนใต้',
#  'นายอลงกรณ์พลบุตร',
#  'เสียงแข็ง',
#  'อึดอัดใจ',
#  'ประกาศณียบัตร',
#  'นายสมชัย ฉัตรพัฒนศิริ',
#  'ตัดสินใจ',
#  'เวเนซูเอลา',
#  'น้อยหน้า',
#  'พรรคชาติไทยยัง',
#  'นายภราดร ศรีชาพันธุ์',
#  'งดเว้น',
#  'รุ่น',
#  'นายวีดี เพด เฮนรี คอนโทไลซ์',
#  'พ.ต.อ.ชิษณุพงษ์ ยุกตะทัต',
#  'ผิดหวัง',
#  'คิดบัญชี',
#  'เขื่อนพระรามหก',
#  'นายมิซาฮิโกะ โคมุระ',
#  'นางสาวสุรัตน์ แซ่จุ่ง',
#  'ยุแหย่',
#  'นายประธาน จิตเที่ยง',
#  'ยั่ว',
#  'ชไนเดอร์',
#  'แป๊บ',
#  'อ.วังทอง',
#  'ทิพ',
#  'หมู่บ้านทานตะวัน',
#  'มิเตอร์',
#  'มิตร',
#  'สันทรายปู่ยี่',
#  'นายประเสริฐ จันทร์แยง',
#  'สาขาบางโล่',
#  'อ.แม่แจ่ม',
#  'ขนมจีน',
#  'บิ๊กเติ้ง',
#  'ปลงศพ',
#  'ด.ญ.เทวธิดา กล้าแข็ง',
#  'บ้านเจาะบันตัง',
#  'มัวเมา',
#  'wing',
#  'ดร.ณัฐ อินทรปาณ',
#  'หรอ',
#  'นายปลอดประสพ สุรัสวดี',
#  'ผีหลอก',
#  'แล็บ',
#  'เสนอแนะ',
#  'บ้านคอลอกาเว',
#  'โรงเรียนบ้านป่าทุ่ง',
#  'เก้า',
#  'บาดเจ็บล้มตาย',
#  'บริษัทมีเดีย ออฟ มีเดียส์',
#  'เจอ',
#  'นายลิขิต จันทร์ปุ่ย',
#  'ธนชาต',
#  'พล.อ.สนธิ',
#  'คลุ้มคลั่ง',
#  '050',
#  'นายยอดธง บุญทู่',
#  'ผศ.น.สพ.ธีระพล',
#  'ผิดชอบชั่วดี',
#  'พลเรือน',
#  'ยา',
#  'นางอภินันท์พรเพชรสุข',
#  'นางปริศนา',
#  'นางเปรมฤดี แก้วเพชร',
#  'เสื่อมโทรม',
#  'หลงใหล',
#  'เจือปน',
#  'องค์การชำนัญพิเศษ',
#  'ถนนภูผาภักดี',
#  'นายปิยะพงศ์ ชลวิวัฒน์มงคล',
#  'เดียงสา',
#  'ยัน',
#  'เกลียด',
#  'นายสุชาติ',
#  'จำนำ',
#  '1271',
#  'สโตร์',
#  'อยุธยา',
#  'เครือข่ายสลัม 4 ภาค',
#  'โครงการพระราชดำริ มูลนิธิชัยพัฒนา',
#  'ส.ต.ท.วิชญ์ภาส มาลีหวล',
#  'เทศบาลตำบลวัฒนานคร',
#  'พ.ต.อ.รณพงษ์ ทรายแก้ว',
#  'จริญญา',
#  'จ.ขอนแก่น',
#  'จอง',
#  'อบจ.นครราชสีมา',
#  'บันดาลใจ',
#  'ทางเดิน',
#  'นายอรรถภูมิ บุณยเกียรติ',
#  'อุทยานแห่งชาติดอยอินทนนท์',
#  'โคปา',
#  'ธชณัฐโชติสิริกุล',
#  'ต.หนองยายดา',
#  'ขบเคี้ยว',
#  'อุดมการณ์',
#  'สถานทูตเดนมาร์ก',
#  'ประกาย',
#  'เมืองทองธานี',
#  'มหาเธร์ฯ',
#  'รุ่งเรือง',
#  'อ.โพธิ์ทอง',
#  'นายวุฒิชัย วัชรีรัตน์',
#  'นางสลินี สรรพศาสตร์',
#  'ตก',
#  'เทอดศักดิ์',
#  'หมอ',
#  'กักขัง',
#  'พญ.กลมพันธ์ ชีวะพันธ์ศรี',
#  'ชีวี',
#  'ดนุพร',
#  'ลิทัวเนีย',
#  'ศรัณย์รัชต์ วิสุทธิธาดา',
#  'แวดล้อม',
#  '1127',
#  'จิอันคาร์โล มัลโดนาโด้',
#  'นายพิชิฏ ชื่นบาน',
#  'นายอดิศร',
#  'ร่มเกล้า',
#  'ซ่อม',
#  'สำนักข่าวรอยเตอร์',
#  'ร.ต.อ.อภิชาติ พรมสงฆ์',
#  'นิค ลาเชย์',
#  'พ.ต.อ.ศุภวัฒน์ ทับเคลียว',
#  'จี',
#  'กาตาร์',
#  'การบินไทย',
#  'พล.ต.ต.วรัญวัส',
#  'สุสานเลนิน',
#  'หนุน',
#  'พ.ต.อ.สักกฉัฐ กิตติขจร',
#  'AB>พล.อ.เปรม ติณสูลานนท์',
#  'แบรด พิทท์',
#  'ด.ญ.กันศา แซ่จาง',
#  'มุด',
#  'ได้',
#  'ยูไนเต็ดแอร์ไลน์',
#  'ศาลพระชัยมงคลภูมิ',
#  'สตริง',
#  'นสพ.ผู้จัดการ',
#  ...}

# %% [markdown]
# # Unigram

# %% [markdown]
# In this section, we will demonstrate how to build a unigram language model <br>
# **Important note:** <br>
# **\<s\>** = sentence start symbol <br>
# **\</s\>** = sentence end symbol

# %%
# lambda example
a = lambda x,y:x*y
print(a(10,2))
# Out:
# 20

# %%
# defaultdict example
test_dict = defaultdict(lambda: 0)
test_dict["A"] = 1
test_dict["B"] = 2

print(test_dict["A"])
print(test_dict["A"])
print(test_dict["C"])
# Out:
# 1
# 1
# 0

# %%
def getUnigramModel(data):
    model = defaultdict(lambda: 0)
    word_count =0
    for sentence in data:
        sentence +=  u'|</s>' #for unigram model we can always ignore <s>, since p(w0=<s>)=1
        for w1 in sentence.split('|'):
            model[w1] +=1.0
            word_count+=1
    for w1 in model:
        model[w1] = model[w1]/(word_count)
    return model

# %%
model = getUnigramModel(train)

# %%
model
# Out:
# defaultdict(<function __main__.getUnigramModel.<locals>.<lambda>()>,
#             {'สงสัย': 0.00037952981516710117,
#              'ติด': 0.000799455130463374,
#              'หวัด': 0.0007026938162004744,
#              'นก': 0.0007026938162004744,
#              ' ': 0.12474694098029546,
#              'อีก': 0.0023156955306606543,
#              'คน': 0.006206815566359003,
#              'ยัง': 0.0035905023603184667,
#              'น่า': 0.0007985157002278118,
#              'ห่วง': 8.266986072946758e-05,
#              '</s>': 0.020364968646515887,
#              'ตาม': 0.0019427417271424881,
#              'ที่': 0.02245050376946382,
#              'นางประนอม ทองจันทร์': 9.394302355621316e-07,
#              'กับ': 0.004522417153996101,
#              'ด.ช.กิตติพงษ์ แหลมผักแว่น': 9.394302355621316e-07,
#              'และ': 0.01204443505014209,
#              'ด.ญ.กาญจนา กรองแก้ว': 9.394302355621316e-07,
#              'ป่วย': 0.00047535169919443856,
#              'เชื้อ': 0.0007252401418539656,
#              'ไข้': 0.0007083303976138472,
#              'ขณะ': 0.0022828154724159797,
#              'นี้': 0.0066530449282510154,
#              'ไม่': 0.011029850395734987,
#              'ดี': 0.0013396275159115996,
#              'ขึ้น': 0.003134878696070833,
#              'หลัง': 0.001976561215622725,
#              'เข้า': 0.003739871767772846,
#              'เยี่ยม': 0.00012024707015195284,
#              'ดู': 0.0006829657812536696,
#              'อาการ': 0.0005054134667324268,
#              'ผู้': 0.0073679513375137975,
#              'แล้ว': 0.0032081542544446793,
#              'น.พ.จรัล': 6.576011648934921e-06,
#              'ประชุม': 0.0010042509218159187,
#              'ร่วม': 0.0015519387491486414,
#              'เจ้าหน้าที่': 0.0016825195518917777,
#              'ทุก': 0.001585758237628878,
#              'ฝ่าย': 0.0009826440263979897,
#              'เพื่อ': 0.00316869818455107,
#              'สรุป': 0.00023767584959721928,
#              'ผล': 0.001713520749665328,
#              'การ': 0.0175316470560605,
#              'ดำเนิน': 0.0007440287465652082,
#              'รวม': 0.0013471429577960967,
#              'ทั้ง': 0.0022086004838065714,
#              'สอบสวน': 0.0008595786655393504,
#              'โรค': 0.000721482420911717,
#              'ก่อน': 0.001412903074285446,
#              'จะ': 0.010533831231358181,
#              'ถูก': 0.0018675873082975175,
#              'ส่ง': 0.0015303318537307122,
#              'มา': 0.008928344958782499,
#              'รักษา': 0.0007055121069071608,
#              'ตัว': 0.0031217266727729632,
#              'จาก': 0.007475046384367881,
#              'นั้น': 0.003293642405880833,
#              'กัน': 0.00345522440639752,
#              'แถลง': 0.0003663777918692313,
#              'ข่าว': 0.0019333474247868667,
#              'โดย': 0.0046539373869748,
#              'กล่าว': 0.005225110970196576,
#              'ว่า': 0.014643838511942507,
#              '3': 0.001741703656732192,
#              'ราย': 0.0013828413067474576,
#              'ทรง': 0.0004960191643768055,
#              'ใน': 0.012740552854693629,
#              'ของ': 0.007778482350454449,
#              'ด.ช.กิตติพงษ์': 9.394302355621316e-07,
#              'ด.ญ.กาญจนา': 9.394302355621316e-07,
#              'ปอด': 9.20641630850889e-05,
#              'หาย': 0.00025458559383733764,
#              'เป็น': 0.010903027313934098,
#              'ปกติ': 0.0004612602456610066,
#              'คาด': 0.0004556236642476338,
#              'กลับ': 0.0009309753634420723,
#              'บ้าน': 0.0020864745531834943,
#              'ได้': 0.012195683318067592,
#              'ช้า': 5.824467460485216e-05,
#              'แต่': 0.0037952981516710116,
#              'นางประนอม': 9.394302355621316e-07,
#              'เป็นห่วง': 0.0001700368726367458,
#              'ซึ่ง': 0.003967213884778882,
#              'ชั้น': 0.00048286714107893564,
#              'ถือ': 0.0007158458394983442,
#              'อยู่': 0.003649686465158881,
#              'ขั้น': 0.00013339909344982267,
#              'อาจ': 0.0008774278400150309,
#              'เพราะ': 0.002405880833274619,
#              'ตรวจ': 0.0008323351887080486,
#              'พบ': 0.0020432607623476363,
#              'มี': 0.013251602902839428,
#              'บวม': 4.8850372249230845e-05,
#              'อักเสบ': 3.100119777355034e-05,
#              'เนื่อง': 0.0009882806078113625,
#              'ไวรัส': 0.00011085276779633152,
#              'แน่ชัด': 2.8182907066863947e-05,
#              'หรือ': 0.0027600460320815427,
#              'ต้อง': 0.004343925409239296,
#              'รอ': 0.00047816998990112496,
#              'ห้อง': 0.0005251415016792316,
#              'ปฏิบัติการ': 5.35475234270415e-05,
#              'ตัวอย่าง': 0.00014655111674769251,
#              'เลือด': 0.00013903567486319546,
#              'ไป': 0.008119495525963503,
#              'พิสูจน์': 0.00011085276779633152,
#              'กรมวิทยาศาสตร์การแพทย์กระทรวงสาธารณสุข': 9.394302355621316e-07,
#              'รพ.ศิริราช': 1.78491744756805e-05,
#              'ทราบ': 0.0010878602127809484,
#              'วัน': 0.0037736912562530826,
#              'สอง': 0.0005101106179102374,
#              'ต่อ': 0.0027713191949082882,
#              'เสีย': 0.0009074896075530191,
#              'ชีวิต': 0.0010681321778341435,
#              'ก่อนหน้า': 0.00027807134972639093,
#              'ข่าย': 8.454872120059185e-05,
#              'ประวัติ': 0.00015970314004556236,
#              'สัมผัส': 7.1396697902722e-05,
#              'ไก่': 0.0008313957584724864,
#              'ตาย': 0.0007308767232673384,
#              'ด้วย': 0.0027196505319523707,
#              'เขต': 0.0005420512459193499,
#              'อ.ขาณุวรลักษบุรี': 9.394302355621316e-07,
#              'เขตกิ่งอ.โกสัมพีนคร': 9.394302355621316e-07,
#              'ส่วน': 0.0032269428591559218,
#              'ระแวง': 9.394302355621316e-06,
#              'กลาย': 0.0001221259306230771,
#              'พันธุ์': 0.00011930763991639071,
#              'ระบาด': 0.00028746565208201223,
#              'สู่': 0.00042744075718076987,
#              'เคย': 0.0007534230489208295,
#              'เกิด': 0.0028380187416331996,
#              'ทั่ว': 0.0003053148265576928,
#              'โลก': 0.00046877568754550365,
#              'ก็': 0.0045336903168228465,
#              'H': 1.690974424011837e-05,
#              '5': 0.001222198736466333,
#              'N': 1.5030883768994105e-05,
#              '1': 0.002426548298456986,
#              'เฉพาะ': 0.0007336950139740248,
#              'สัตว์': 0.0003889241175227225,
#              'ปีก': 0.0001935226285257991,
#              'เพิ่ง': 0.00014467225627656826,
#              'เมื่อ': 0.002905657718593673,
#              'ต้น': 0.0005937199088752672,
#              'ปี': 0.0025101575894220154,
#              'ผ่าน': 0.001462692876770239,
#              'ไทย': 0.0011686512130392917,
#              'ตั้งแต่': 0.0006275393973555038,
#              '2546': 3.2880058244674604e-05,
#              'ยืนยัน': 0.000549566687803847,
#              'เพียง': 0.000785363676929942,
#              '13': 0.00024613072171727845,
#              '9': 0.0003588623499847343,
#              'เดียว': 0.0010934967941943212,
#              'จ.ปราจีนบุรี': 1.690974424011837e-05,
#              'ข้อมูล': 0.0005833861762840837,
#              'แพร่': 0.00014467225627656826,
#              'รักษาการ': 0.0004311984781230184,
#              'ปลัด': 0.00023391812865497077,
#              'กระทรวงสาธารณสุข': 0.00010897390732520726,
#              'อย่าง': 0.0033161887315343243,
#              'ไร': 0.0009910988985180487,
#              'ก็ตาม': 0.000563658141337279,
#              'กรณี': 0.0007919396885788769,
#              'จ.กำแพงเพชร': 2.8182907066863946e-06,
#              'ศึกษา': 0.0004885037224923084,
#              'สนใจ': 0.00020009864017473403,
#              'ชิ้นส่วน': 2.7243476831301816e-05,
#              'ตรวจสอบ': 0.0012804434110711854,
#              'ใกล้ชิด': 0.00020009864017473403,
#              'กุญแจ': 2.5364616360177554e-05,
#              'ดอก': 0.00011461048873858005,
#              'สำคัญ': 0.0005119894783813617,
#              'เพิ่มเติม': 0.00022264496582822518,
#              'มั่นใจ': 0.00023297869841940863,
#              'คง': 0.0006970572347871016,
#              'ง่าย': 0.00011179219803189366,
#              'ๆ': 0.0013837807369830198,
#              'เรื่อง': 0.002861504497522253,
#              'พ.ต.ท.ทักษิณ ชินวัตร': 0.0001841283261701778,
#              'นายก': 0.00142793395805444,
#              'รัฐมนตรี': 0.0012766856901289367,
#              'พอใจ': 0.0001249442213297635,
#              'ทำ': 0.005019375748608469,
#              'งาน': 0.002664224148054205,
#              'เกี่ยวข้อง': 0.0005054134667324268,
#              'ฯ': 0.0012081072829329012,
#              'กำชับ': 9.582188402733742e-05,
#              'ให้': 0.011133187721646821,
#              'รีบ': 0.0001606425702811245,
#              'ลง': 0.0018995279363066301,
#              'ดูแล': 0.0005683552925150896,
#              'ควบคุม': 0.00038516639658047396,
#              'พื้นที่': 0.0018093426336926654,
#              'ทาง': 0.0024819746823551516,
#              'ด้าน': 0.0014420254115878718,
#              'นายกมล เจริญเกษ': 9.394302355621316e-07,
#              'ปศุสัตว์': 3.2880058244674604e-05,
#              'กำแพงเพชร': 1.5030883768994105e-05,
#              'เผย': 0.0002733741985485803,
#              'จังหวัด': 0.0007599990605697644,
#              'ประกาศ': 0.0005251415016792316,
#              'สี': 0.00045750252471875807,
#              'แดง': 0.00011554991897414219,
#              'ดัง': 0.001928650273609056,
#              'สามารถ': 0.001434509969703375,
#              'ทำลาย': 0.0002085535122947932,
#              'ถ้า': 0.0006914206533737288,
#              'ใด': 0.0006322365485333146,
#              'กำลัง': 0.0010014326311092322,
#              'หนัก': 0.0003363160243312431,
#              'หนังสือพิมพ์': 0.00012306536085863922,
#              'ไทยรัฐ': 1.0333732591183447e-05,
#              '55': 4.978980248479297e-05,
#              'ฉบับ': 0.00021043237276591748,
#              '17052': 9.394302355621316e-07,
#              '/': 0.00040019728034946806,
#              '28': 0.00013809624462763335,
#              '2004': 5.1668662955917235e-05,
#              'แนว': 0.00022546325653491158,
#              'รบ': 3.9456069893609526e-05,
#              'อาหาร': 0.0003626200709269828,
#              'ปลอด': 0.000499776885319054,
#              'ภัย': 0.0007910002583433148,
#              'วิกฤต': 3.1940628009112476e-05,
#              '"': 0.005321872284459475,
#              'สิ่ง': 0.00048756429225674627,
#              'จำเป็น': 0.00024331243101059208,
#              'มนุษย์': 4.603208154254445e-05,
#              'เท่า': 0.0007102092580849714,
#              'จึง': 0.0020864745531834943,
#              'คุณค่า': 1.3152023297869842e-05,
#              'ร่างกาย': 0.00017943117499236714,
#              'บริโภค': 0.00012400479109420136,
#              'รับ': 0.0034946804762911294,
#              'ระบบ': 0.000371074943047042,
#              'คุณภาพ': 5.918410484041429e-05,
#              'ขั้นตอน': 0.000178491744756805,
#              'ด้วยเหตุนี้': 9.394302355621316e-07,
#              'รัฐบาล': 0.001099133375607694,
#              '2547': 4.039550012917166e-05,
#              'นโยบาย': 0.0002790107799619531,
#              'แรก': 0.0005345358040348528,
#              'ทำท่า': 2.8182907066863946e-06,
#              'หน่วยงาน': 0.00011648934920970431,
#              'กระทรวงเกษตรฯ': 6.669954672491133e-05,
#              '(': 0.002197327320979826,
#              'สธ.': 6.669954672491133e-05,
#              ')': 0.0022649662979402994,
#              'เร่ง': 0.0002677376171352075,
#              'รูปธรรม': 1.5030883768994105e-05,
#              'วิกฤตการณ์': 5.636581413372789e-06,
#              'ถึง': 0.0025853120082669863,
#              'ออก': 0.002826745578806454,
#              'เซ': 1.8788604711242631e-06,
#              'คณะ': 0.0010728293290119542,
#              '22': 0.000178491744756805,
#              'กุมภาพันธ์': 8.266986072946758e-05,
#              'อนุมัติ': 0.00015312712839662745,
#              'งบ': 0.0003100119777355034,
#              'ประมาณ': 0.0009375513750910073,
#              '271': 2.8182907066863946e-06,
#              'ล้าน': 0.0007534230489208295,
#              'บาท': 0.0011479837478569248,
#              'ใช้': 0.0021804175767397072,
#              'โครงการ': 0.0003626200709269828,
#              'มอบ': 0.00026304046595739683,
#              'หลัก': 0.0003363160243312431,
#              'ประสาน': 0.00039080297799384676,
#              'แผน': 0.0003410131755090538,
#              'ยุทธศาสตร์': 4.978980248479297e-05,
#              'บูรณาการ': 6.576011648934921e-06,
#              'ความ': 0.006589163672232791,
#              'ร่วมมือ': 0.00026679818689964534,
#              'ระหว่าง': 0.0006904812231381667,
#              'ภาค': 0.0009704314333356819,
#              'รัฐ': 0.0003043753963221306,
#              'เอกชน': 0.0001719157331078701,
#              'เสนอ': 0.0006632377463068648,
#              'มาตรการ': 0.000271495338077456,
#              'พิจารณา': 0.0006651166067779892,
#              'ห่วงโซ่': 9.394302355621316e-07,
#              'ชัดเจน': 0.0003363160243312431,
#              'รับผิดชอบ': 0.00024049414030390568,
#              'คือ': 0.0012804434110711854,
#              'สำนักงานอาหารและยา': 9.394302355621316e-07,
#              'อย.': 1.4091453533431974e-05,
#              'กรมอนามัย': 5.636581413372789e-06,
#              'กรมวิทยาศาสตร์การแพทย์': 2.3485755889053288e-05,
#              'ศ.ดร.ภักดี โพธิศิริ': 1.8788604711242631e-06,
#              'รอง': 0.001085981352309824,
#              'พัฒนา': 0.00022452382629934944,
#              'มาตรฐาน': 9.018530261396463e-05,
#              'กฎหมาย': 0.0006482068625378708,
#              'สากล': 1.690974424011837e-05,
#              ',': 0.0014814814814814814,
#              'เข้มแข็ง': 4.978980248479297e-05,
#              'กำกับ': 5.918410484041429e-05,
#              'ศักยภาพ': 3.663777918692313e-05,
#              'บุคลากร': 3.9456069893609526e-05,
#              'กระบวนการ': 9.20641630850889e-05,
#              'สุดท้าย': 0.0002170083844148524,
#              'แนวโน้ม': 7.797270955165692e-05,
#              'สาร': 0.00010333732591183447,
#              'ปนเปื้อน': 9.394302355621316e-06,
#              'ลด': 0.0004142887338829,
#              'แนะนำ': 9.957960496958595e-05,
#              'วิธี': 0.00022076610535710093,
#              'เลือก': 0.0003231640010333733,
#              'ซื้อ': 0.0004612602456610066,
#              'สินค้า': 0.00025740388454402403,
#              'เช่น': 0.000806970572347871,
#              'หมู': 2.5364616360177554e-05,
#              'แสดง': 0.0005946593391108292,
#              'เนื้อ': 8.266986072946758e-05,
#              'ผัก': 4.509265130698231e-05,
#              'สด': 0.00013339909344982267,
#              'สะอาด': 5.824467460485216e-05,
#              'กรอบ': 0.00010145846544071021,
#              'ปราศจาก': 1.5030883768994105e-05,
#              'แมลง': 3.5698348951361e-05,
#              'รบกวน': 1.1273162826745578e-05,
#              'ปลา': 4.509265130698231e-05,
#              'ฯลฯ': 2.1606895417929025e-05,
#              'ต้องการ': 0.0004960191643768055,
#              'หลายหลาก': 9.394302355621316e-07,
#              'เอง': 0.0008980953051973977,
#              'ผลิต': 0.00017755231452124286,
#              'สนอง': 2.3485755889053288e-05,
#              'เคมี': 1.878860471124263e-05,
#              'ชนิด': 0.0001728551633434322,
#              'ต่างๆ': 0.0006632377463068648,
#              'กว่า': 0.0014730266093614223,
#              'รู้': 0.0006247211066488174,
#              'นัก': 0.00155569647009089,
#              'สะสม': 3.4758918715798866e-05,
#              'จน': 0.0007806665257521313,
#              'ภาวะ': 0.00017379459357899434,
#              'ร้ายแรง': 4.6971511778106576e-05,
#              'ช่วย': 0.0007459076070363324,
#              'มือ': 0.0003485286173935508,
#              'ปรากฎ': 2.6304046595739685e-05,
#              'ปริมาณ': 0.00019446205876136124,
#              'พิษ': 7.797270955165692e-05,
#              'ตกค้าง': 1.1273162826745578e-05,
#              'จำนวน': 0.0012212593062307711,
#              'ทั้งนี้': 0.0007026938162004744,
#              'เดือน': 0.0006735714788980484,
#              'มีนาคม': 4.509265130698231e-05,
#              'มกราคม': 6.951783743159773e-05,
#              'ถึงแม้': 3.5698348951361e-05,
#              'ประเทศ': 0.001056859015007398,
#              'อันตราย': 0.00014373282604100612,
#              'ยังคง': 0.00027807134972639093,
#              'ยา': 0.00045938138518988235,
#              'บาง': 0.0006604194556001784,
#              'นพ.ศุภชัย คุณารัตนพฤกษ์': 9.394302355621316e-07,
#              'เลขาธิการ': 0.0002583433147795862,
#              'คณะกรรมการอาหารและยา': 1.8788604711242631e-06,
#              'ยอม': 0.0005176260597947345,
#              'ฆ่า': 0.00037671152446041477,
#              'ปัญหา': 0.001412903074285446,
#              'เกิน': 0.0003607412104558585,
#              '4': 0.001036191549825031,
#              '.': 0.0026745578806453884,
#              '47': 3.663777918692313e-05,
#              'กังวลใจ': 6.576011648934921e-06,
#              'หนึ่ง': 0.0009760680147490547,
#              'เลขา': 4.509265130698231e-05,
#              'ระบุ': 0.0007468470372718946,
#              'จุลินทรีย์': 3.7577209422485262e-06,
#              'ขนส่ง': 6.482068625378708e-05,
#              'วาง': 0.0005251415016792316,
#              'จำหน่าย': 0.00018506775640573993,
#              'แปร': 1.9728034946804763e-05,
#              'รูป': 0.0001606425702811245,
#              'ติดตาม': 0.0003992578501139059,
#              'โรง': 0.0008032128514056225,
#              'เสี่ยง': 0.0001512482679255032,
#              'จีเอ็มพี': 2.8182907066863946e-06,
#              '453': 1.8788604711242631e-06,
#              '6': 0.000792879118814439,
#              '887': 1.8788604711242631e-06,
#              'แห่ง': 0.0005984170600530778,
#              '75': 2.8182907066863947e-05,
#              '%': 0.00019728034946804763,
#              '64': 2.6304046595739685e-05,
#              'ตั้ง': 0.0007562413396275159,
#              'เป้า': 6.85784071960356e-05,
#              'ไว้': 0.0012043495619906528,
#              'ภาย': 0.0009084290377885813,
#              'สิ้น': 6.200239554710068e-05,
#              'ครบ': 0.00016533972145893515,
#              '100': 0.00022170553559266304,
#              '80': 0.00011648934920970431,
#              'เตรียม': 0.0005833861762840837,
#              'ขอ': 0.0016909744240118367,
#              'ปรับปรุง': 8.454872120059185e-05,
#              'ตลาด': 0.00023016040771272223,
#              'นอก': 0.0009431879565043801,
#              'แผงลอย': 7.5154418844970525e-06,
#              'นานา': 6.106296531153855e-05,
#              'ละเลย': 1.3152023297869842e-05,
#              'ป้าย': 0.00011367105850301792,
#              '76': 2.1606895417929025e-05,
#              '000': 0.0004556236642476338,
#              'ชั่วคราว': 0.00012400479109420136,
#              '61': 8.454872120059185e-06,
#              '792': 1.8788604711242631e-06,
#              'ทอง': 7.891213978721905e-05,
#              '14': 0.00026961647760633174,
#              '297': 2.8182907066863946e-06,
#              'ต่อเนื่อง': 0.00025740388454402403,
#              'ลักลอบ': 7.515441884497053e-05,
#              'ร้าน': 0.00039174240822940887,
#              'เจ้าภาพ': 3.381948848023674e-05,
#              'น.พ.วิชัย เทียนถาวร': 9.394302355621316e-07,
#              'อธิบดี': 0.0004020761408205923,
#              '138': 2.5364616360177554e-05,
#              '510': 2.8182907066863946e-06,
#              'รสชาติ': 8.454872120059185e-06,
#              'อร่อย': 8.454872120059185e-06,
#              '23': 0.0001606425702811245,
#              '055': 9.394302355621316e-07,
#              'คิด': 0.0008220014561168651,
#              '16': 0.0003034359660865685,
#              '65': 3.4758918715798866e-05,
#              'สำหรับ': 0.0007017543859649122,
#              'จัดสรร': 2.5364616360177554e-05,
#              'ต่าง': 0.0007383921651518354,
#              'บอก': 0.000606871932173137,
#              'เสียง': 0.00037013551281147986,
#              'เพียงพอ': 9.770074449846169e-05,
#              '2': 0.002284694332887104,
#              'ยาก': 0.00010333732591183447,
#              'ระดม': 7.1396697902722e-05,
#              'สรรพกำลัง': 9.394302355621316e-07,
#              'หลาย': 0.0009431879565043801,
#              'แก้': 0.0003372554545668052,
#              'ยั่งยืน': 2.3485755889053288e-05,
#              'ท้องไร่ท้องนา': 9.394302355621316e-07,
#              'ฟาร์ม': 9.300359332065102e-05,
#              'เกษตรกร': 0.00015312712839662745,
#              'มาก': 0.0020592310763521923,
#              'ระยะ': 0.0004039550012917166,
#              'ยาว': 0.00017097630287230795,
#              'ส่งผล': 9.394302355621316e-06,
#              'นพ.สถาพร วงษ์เจริญ': 9.394302355621316e-07,
#              'ปรับ': 0.0004894431527278705,
#              'โฉม': 2.8182907066863946e-06,
#              'ครั้ง': 0.0015810610864510674,
#              'ใหญ่': 0.001063435026656333,
#              'เพิ่ม': 0.000720542990676155,
#              'นำ': 0.002685831043472134,
#              'แผง': 4.509265130698231e-05,
#              'ขาย': 0.0005223232109725452,
#              'ปล่อย': 0.00024613072171727845,
#              'เงิน': 0.0012128044341107118,
#              'กู้': 0.00010991333756076939,
#              'ค้า': 0.0003015571056154442,
#              'ดอกเบี้ย': 4.791094201366871e-05,
#              'ปราการ': 2.8182907066863946e-06,
#              'ด่าน': 6.482068625378708e-05,
#              'ครัว': 1.9728034946804763e-05,
#              'สร้าง': 0.0006679348974846756,
#              'ควบคู่': 1.690974424011837e-05,
#              'ประชาสัมพันธ์': 6.388125601822495e-05,
#              'สื่อ': 0.0011667723525681673,
#              'รณรงค์': 6.482068625378708e-05,
#              'จัด': 0.0009478851076821907,
#              'มหกรรม': 5.730524436929002e-05,
#              'ระดับ': 0.0007243007116184034,
#              'กลุ่ม': 0.001120740271025623,
#              'น้อย': 0.0003475891871579887,
#              'มัธยม': 1.878860471124263e-05,
#              'พฤติกรรม': 0.0001606425702811245,
#              'ถูกต้อง': 0.00018882547734798844,
#              'บรรลุ': 1.0333732591183447e-05,
#              'เป้าหมาย': 0.00012682308180088776,
#              'อะไร': 0.00077127222339651,
#              'สะดุด': 9.394302355621316e-06,
#              '10': 0.000821062025881303,
#              'สถานการณ์': 0.0005382935249771014,
#              'นิ่ง': 2.4425186124615422e-05,
#              'ยอด': 0.0001399751050987576,
#              'คงที่': 7.5154418844970525e-06,
#              'ศูนย์': 9.112473284952677e-05,
#              'รายงาน': 0.0011151036896122502,
#              'เดิม': 0.00043213790835858055,
#              '7': 0.0005082317574391132,
#              'ทั้งหมด': 0.000592780478639705,
#              '21': 0.00027243476831301813,
#              '12': 0.00029028394278869863,
#              'นอน': 0.0001878860471124263,
#              'พยาบาล': 0.0002611616054862726,
#              'น.พ.ธวัช สุนทราจารย์': 6.576011648934921e-06,
#              'ฐานะ': 0.0002837079311397637,
#              'อำนวย': 0.0002818290706686395,
#              'สัมภาษณ์': 0.00026961647760633174,
#              'มี.ค.': 2.0667465182366894e-05,
#              'จังหวัดชัยนาท': 4.697151177810658e-06,
#              'นครราชสีมา': 4.039550012917166e-05,
#              'เฝ้า': 0.0003128302684421898,
#              'ระวัง': 0.0002949810939665093,
#              '128': 2.8182907066863946e-06,
#              'ชาว': 0.0011911975386927828,
#              'วาน': 7.985157002278118e-05,
#              'ชัยนาท': 1.1273162826745578e-05,
#              'วิเคราะห์': 0.0001042767561473966,
#              'รอบ': 0.0003898635477582846,
#              'ละ': 0.0009676131426289955,
#              'เหลือ': 0.0002677376171352075,
#              '-': 0.0021240517626059793,
#              'ประกอบ': 0.0005270203621503558,
#              'ช่วง': 0.0010380704102961554,
#              'อากาศ': 0.0001907043378191127,
#              'เริ่ม': 0.00040019728034946806,
#              'ร้อน': 8.830644214284037e-05,
#              'ประชาชน': 0.0016036074121045585,
#              'เข้าใจ': 0.000328800582446746,
#              'ป้องกัน': 0.0004171070245895864,
#              'ใหม่': 0.0008473660724770427,
#              'เห็น': 0.0013311726437915405,
#              'ชัด': 7.42149886094084e-05,
#              'สาเหตุ': 0.00024519129148171633,
#              'เวลา': 0.0021945090302731393,
#              'นาน': 0.0003475891871579887,
#              'จำแนก': 1.3152023297869842e-05,
#              'เกณฑ์': 4.978980248479297e-05,
#              'องค์การอนามัยโลก': 7.233612813828413e-05,
#              'กรรมการ': 0.0006651166067779892,
#              'เชี่ยวชาญ': 0.00012870194227201202,
#              'คลินิก': 3.2880058244674604e-05,
#              'กรมควบคุมโรค': 3.757720942248526e-05,
#              'เรื่อย': 7.703327931609478e-05,
#              'ควร': 0.000557082129688344,
#              'ตระหนก': 9.394302355621316e-06,
#              'ประปราย': 3.7577209422485262e-06,
#              'ย่าง': 2.1606895417929025e-05,
#              'หน้า': 0.0008811855609572794,
#              'นพ.จรัล ตฤณวุฒิพงษ์': 3.7577209422485262e-06,
#              'อำเภอเมือง': 1.4091453533431974e-05,
#              'จังหวัดนครราชสีมา': 7.5154418844970525e-06,
#              'เมื่อวาน': 6.576011648934921e-06,
#              'ก.พ.': 9.112473284952677e-05,
#              'แม้': 0.0003203457103266869,
#              'บุคคล': 0.0004048944315272787,
#              'ฟัก': 3.7577209422485262e-06,
#              'หาก': 0.0012672913877733154,
#              'อาศัย': 0.00019164376805467484,
#              'วินิจฉัย': 8.830644214284037e-05,
#              'ธรรมดา': 4.8850372249230845e-05,
#              'ทั่วไป': 0.00018318889593461565,
#              'อย่างเช่น': 2.8182907066863946e-06,
#              'จังหวัดพัทลุง': 4.697151177810658e-06,
#              'แต่อย่างใด': 0.00015594541910331385,
#              'เข้มงวด': 8.736701190727824e-05,
#              'ตลอด': 0.0005063528969679889,
#              'เหลือง': 0.0001869466168768642,
#              'บัญชี': 0.0001813100354634914,
#              'เช่นเดียวกับ': 7.5154418844970525e-06,
#              'เดิน': 0.0003654383616336692,
#              'หายใจ': 7.515441884497053e-05,
#              'เฉียบพลัน': 8.454872120059185e-06,
#              'รุนแรง': 0.0003156485591488762,
#              'ซาร์ส': 3.381948848023674e-05,
#              'นพ.จรัล': 1.8788604711242631e-06,
#              'บ้าง': 0.0002818290706686395,
#              'เป็นต้นไป': 1.8788604711242631e-06,
#              'โอกาส': 0.0003522863383357993,
#              'ตื่นตระหนก': 3.757720942248526e-05,
#              'เตือน': 0.0002733741985485803,
#              'พร้อมกับ': 1.0333732591183447e-05,
#              'ท้องร่วง': 9.394302355621316e-07,
#              'เป็นต้น': 0.00010051903520514807,
#              'ระมัดระวัง': 0.0001042767561473966,
#              'น้ำ': 0.0020526550647032575,
#              'ปรุง': 4.791094201366871e-05,
#              'สุก': 7.985157002278118e-05,
#              'ดื่ม': 0.0001550059888677517,
#              'แล็บ': 2.7243476831301816e-05,
#              'หญิง': 0.0002865262218464501,
#              'ลพบุรี': 1.878860471124263e-05,
#              'แพทย์': 0.00040019728034946806,
#              '25': 0.00016158200051668664,
#              'เลี้ยง': 0.0002686770473707696,
#              'ชน': 0.0004903825829634327,
#              'ทยอย': 8.36092909650297e-05,
#              'หมด': 0.0002865262218464501,
#              'เครื่อง': 0.0006529040137156814,
#              'ล่าสุด': 0.0003118908382066277,
#              'ประเทศไทย': 0.0003541651988069236,
#              'น.พ.จรัล ตฤณวุฒิพงษ์': 6.576011648934921e-06,
#              '27': 0.00012306536085863922,
#              'แทน': 0.00042650132694520775,
#              'เอช': 2.0667465182366894e-05,
#              'เอ็น': 1.9728034946804763e-05,
#              'อายุ': 0.0010324338288827826,
#              'อาชีพ': 0.00016533972145893515,
#              'จ้าง': 0.0001869466168768642,
#              'ถู': 1.8788604711242631e-06,
#              'พื้น': 6.85784071960356e-05,
#              'โรงพยาบาลลพบุรี': 3.7577209422485262e-06,
#              '60': 0.0001719157331078701,
#              'เล้า': 4.697151177810658e-06,
#              'ทิ้ง': 0.00014655111674769251,
#              'ขยะ': 5.824467460485216e-05,
#              'เทศบาล': 7.609384908053265e-05,
#              'เผา': 7.891213978721905e-05,
#              'ฝัง': 6.482068625378708e-05,
#              'ใส่': 0.0003137696986777519,
#              'ไอ': 2.4425186124615422e-05,
#              'เจ็บ': 9.394302355621315e-05,
#              'คอ': 0.0001606425702811245,
#              '20': 0.0005326569435637286,
#              'ธันวาคม': 6.388125601822495e-05,
#              'จนถึง': 0.00017097630287230795,
#              'ปัจจุบัน': 0.0002846473613753259,
#              'หัวหน้า': 0.000549566687803847,
#              '136': 1.1273162826745578e-05,
#              'หวั่น': 8.92458723784025e-05,
#              'เจ้าของ': 0.0002621010357218347,
#              'แมว': 9.488245379177529e-05,
#              'จ.นครปฐม': 2.4425186124615422e-05,
#              'ย้ำ': 0.00013527795392094695,
#              'ตัด': 0.00018976490758355058,
#              'วงจร': 4.978980248479297e-05,
#              'ทันที': 0.00026304046595739683,
#              'โฆษก': 0.0002527067333662134,
#              'หา': 0.001271988538951126,
#              'พร้อม': 0.0015087249583127832,
#              'องค์การสุขภาพสัตว์โลก': 2.8182907066863946e-06,
#              'ทักษิณ': 0.0003175274196200005,
#              'หารือ': 0.0003137696986777519,
#              'ครม.': 0.00024331243101059208,
#              'เวียดนาม': 5.730524436929002e-05,
#              'ระบาดวิทยา': 4.697151177810658e-06,
#              'จังหวัดนครปฐม': 3.7577209422485262e-06,
#              'ข้าม': 0.00011461048873858005,
#              'สัตวแพทยศาสตร์': 3.7577209422485262e-06,
#              'มหาวิทยาลัยเกษตรศาสตร์กำแพงแสน': 9.394302355621316e-07,
#              'เปรียบเทียบ': 6.669954672491133e-05,
#              'คล้ายคลึง': 4.697151177810658e-06,
#              'ร้อย': 0.0006237816764132554,
#              'เปอร์เซ็นต์': 4.6971511778106576e-05,
#              'วิทยาศาสตร์': 3.381948848023674e-05,
#              'สายพันธุ์': 2.0667465182366894e-05,
#              'เอ': 4.603208154254445e-05,
#              'ประเภท': 7.891213978721905e-05,
#              'ได้แก่': 0.00019258319829023698,
#              'สุกร': 3.7577209422485262e-06,
#              'ม้า': 1.3152023297869842e-05,
#              'เกรง': 0.0001371568143920712,
#              'กังวล': 5.918410484041429e-05,
#              'ประเด็น': 0.0002940416637309472,
#              'ผสม': 5.448695366260363e-05,
#              'รู้จัก': 0.00013621738415650907,
#              'พาหะ': 1.78491744756805e-05,
#              'จำกัด': 5.730524436929002e-05,
#              'ขอบเขต': 1.3152023297869842e-05,
#              'วง': 0.00010615561661852087,
#              'แคบ': 2.8182907066863946e-06,
#              'ที่สุด': 0.0005439301063904742,
#              'ประสิทธิภาพ': 5.35475234270415e-05,
#              'สอดคล้อง': 5.35475234270415e-05,
#              'คำ': 0.0009441273867399423,
#              'จริง': 0.0006294182578266282,
#              'นายจักรภพ เพ็ญแข': 6.576011648934921e-06,
#              'ประจำ': 0.00048004885037224924,
#              'สำนักนายกรัฐมนตรี': 7.233612813828413e-05,
#              'แจ้ง': 0.0009478851076821907,
#              'อำเภอศาลายา': 9.394302355621316e-07,
#              'กิน': 0.00024237300077502993,
#              'ซาก': 5.730524436929002e-05,
#              'ใคร': 0.0006265999671199418,
#              'อธิบาย': 3.9456069893609526e-05,
#              'อื่น': 0.0005758707343995866,
#              'ใช่': 0.0005270203621503558,
#              'คณบดี': 1.9728034946804763e-05,
#              'สัตวแพทย์': 1.4091453533431974e-05,
#              'สถาบัน': 0.00010615561661852087,
#              'โอไออี': 9.394302355621316e-07,
#              'องค์การ': 2.2546325653491157e-05,
#              'เรียบร้อย': 0.0001841283261701778,
#              'นายจักรภพ': 8.454872120059185e-06,
#              'แม้ว': 2.4425186124615422e-05,
#              'ตรง': 0.0003325583033889946,
#              'มหาวิทยาลัยเกษตรศาสตร์': 1.0333732591183447e-05,
#              'ดิบ': 4.133493036473379e-05,
#              'ภูมิต้านทาน': 1.1273162826745578e-05,
#              'ไข่': 0.00011648934920970431,
#              'ถุง': 0.00012024707015195284,
#              'ผ้า': 8.36092909650297e-05,
#              'ปิด': 0.0003466497569224266,
#              'ปาก': 0.00015312712839662745,
#              'ใกล้': 0.00020291693088142043,
#              'ขี้': 1.878860471124263e-05,
#              'เร็ว': 0.0003400737452734916,
#              'ฟูเจียนฟลู': 3.7577209422485262e-06,
#              'พฤษภาคม': 4.978980248479297e-05,
#              'มิถุนายน': 0.000142793395805444,
#              'อย่า': 0.0002658587566640832,
#              'ทางการ': 0.00010897390732520726,
#              'เมืองดานัง': 5.636581413372789e-06,
#              'ประเทศเวียดนาม': 1.5970314004556238e-05,
#              'เปิดเผย': 0.0005777495948707109,
#              'พลังงาน': 3.4758918715798866e-05,
#              'เชื่อม': 5.542638389816576e-05,
#              'เส้นทาง': 0.0001662791516944973,
#              'คมนาคม': 3.4758918715798866e-05,
#              'สาธารณสุข': 7.985157002278118e-05,
#              'เน้น': 0.00013245966321426056,
#              'ข้อมูลข่าวสาร': 2.6304046595739685e-05,
#              'พร้อมทั้ง': 1.5970314004556238e-05,
#              'คาดหวัง': 2.7243476831301816e-05,
#              'เพื่อนบ้าน': 4.509265130698231e-05,
#              'พลัง': 3.381948848023674e-05,
#              'ภูมิภาค': 4.978980248479297e-05,
#              'แข็งแรง': 7.891213978721905e-05,
#              'ท่องเที่ยว': 0.0002555250240728998,
#              'ทุน': 0.0003203457103266869,
#              'แต่ละ': 0.000249888442659527,
#              'ขยาย': 0.00023016040771272223,
#              'ประเทศลาว': 1.4091453533431974e-05,
#              'รพ.สัตว์': 9.394302355621316e-07,
#              'ม.เกษตร': 9.394302355621316e-07,
#              'ยัน': 0.0001907043378191127,
#              '!': 3.381948848023674e-05,
#              'นครปฐม': 1.1273162826745578e-05,
#              'นับ': 0.00023485755889053288,
#              'ปรากฎการณ์': 9.394302355621316e-07,
#              'ติดต่อ': 0.00026679818689964534,
#              'แนะ': 7.703327931609478e-05,
#              'สังเกต': 0.00017473402381455649,
#              'ขน': 8.548815143615397e-05,
#              'พอง': 4.697151177810658e-06,
#              'ฟู': 2.8182907066863946e-06,
#              'ผิด': 0.0007618779210408887,
#              'ฮู': 7.5154418844970525e-06,
#              'แน่นอน': 0.00023297869841940863,
#              'นายสัตวแพทย์ธานีรัตน์ สานติวัตร': 9.394302355621316e-07,
#              'คณะสัตวแพทยศาสตร์': 2.8182907066863946e-06,
#              'โรงพยาบาลสัตว์ มหาวิทยาลัยเกษตรศาสตร์': 1.8788604711242631e-06,
#              'ประวัติศาสตร์': 3.1940628009112476e-05,
#              '15': 0.00044528993165645036,
#              'ตรงข้าม': 8.830644214284037e-05,
#              'เบื้อง': 0.0003457103266868644,
#              'สันนิษฐาน': 3.4758918715798866e-05,
#              'กระทรวงทรัพยากรธรรมชาติและสิ่งแวดล้อม': 2.3485755889053288e-05,
#              'ทส.': 3.663777918692313e-05,
#              'เสือ': 1.9728034946804763e-05,
#              'สวนสัตว์เขาเขียว': 2.8182907066863946e-06,
#              'จ.ชลบุรี': 2.6304046595739685e-05,
#              'เสือลายเมฆ': 3.7577209422485262e-06,
#              'ตระหนัก': 3.006176753798821e-05,
#              'อ่อนเพลีย': 4.697151177810658e-06,
#              'หลีกเลี่ยง': 3.851663965804739e-05,
#              'อนามัยโลก': 5.636581413372789e-06,
#              'ศ.เกียรติคุณ': 3.7577209422485262e-06,
#              'นพ.ประเสริฐ ทองเจริญ': 9.394302355621316e-07,
#              'ที่ปรึกษา': 0.00015688484933887596,
#              'ค้น': 0.0002170083844148524,
#              'ตื่นเต้น': 1.3152023297869842e-05,
#              'วิชาการ': 0.000107095046854083,
#              'ยก': 0.00018976490758355058,
#              'บทเรียน': 1.878860471124263e-05,
#              'โคโรน่า': 3.7577209422485262e-06,
#              'ชะมด': 9.394302355621316e-07,
#              'ตระกูล': 1.0333732591183447e-05,
#              'สิงคโปร์': 9.018530261396463e-05,
#              'ฮ่องกง': 3.757720942248526e-05,
#              'ทั้งที่': 2.7243476831301816e-05,
#              'วิงวอน': 6.576011648934921e-06,
#              'รังเกียจ': 3.7577209422485262e-06,
#              'รัก': 0.000178491744756805,
#              'เม็ด': 4.133493036473379e-05,
#              'เลี้ยงดู': 1.878860471124263e-05,
#              'รับประทาน': 8.36092909650297e-05,
#              "'": 1.0333732591183447e-05,
#              'ชื่อ': 0.0006331759787688766,
#              'แคท': 1.8788604711242631e-06,
#              'ไทยแลนด์': 1.0333732591183447e-05,
#              'สถานที่': 0.0001869466168768642,
#              'กระจาย': 0.00011648934920970431,
#              'ลูก': 0.0006735714788980484,
#              'นม': 7.1396697902722e-05,
#              'ต่ำ': 0.0002113718030014796,
#              'วิตก': 3.100119777355034e-05,
#              'เหตุ': 0.001677822400713967,
#              'ธรรมชาติ': 7.703327931609478e-05,
#              'ประเทศจีน': 1.690974424011837e-05,
#              'ฉีด': 4.4153221071420185e-05,
#              'ทดลอง': 5.824467460485216e-05,
#              'ชิกเกน': 9.394302355621316e-07,
#              '231': 4.697151177810658e-06,
#              'A': 1.1273162826745578e-05,
#              'Chicken': 9.394302355621316e-07,
#              'Thailand': 8.454872120059185e-06,
#              'เสือขาว': 3.7577209422485262e-06,
#              'เรียก': 0.00038798468728716036,
#              'ไทเกอร์': 2.8182907066863946e-06,
#              '022': 3.7577209422485262e-06,
#              'Tiger': 9.394302355621316e-07,
#              'ลีโอพาร์ด': 9.394302355621316e-07,
#              '032': 3.7577209422485262e-06,
#              'Leopard': 9.394302355621316e-07,
#              '202': 2.8182907066863946e-06,
#              'Cat': 9.394302355621316e-07,
#              'ปรากฏ': 0.00018976490758355058,
#              'พี': 2.8182907066863946e-06,
#              'เอเวียน': 3.7577209422485262e-06,
#              'อินฟลูเอนซา': 1.8788604711242631e-06,
#              'Hight': 9.394302355621316e-07,
#              'Polygenic': 9.394302355621316e-07,
#              'Avain': 9.394302355621316e-07,
#              'Influenza': 4.697151177810658e-06,
#              'อีกทั้ง': 1.5970314004556238e-05,
#              'เช้า': 0.00020949294253035534,
#              'นายสัตวแพทย์ธีรพล ศิรินฤมิตร': 9.394302355621316e-07,
#              'วิจัย': 0.00012400479109420136,
#              'ตอกย้ำ': 1.4091453533431974e-05,
#              'เย็น': 9.676131426289955e-05,
#              'เพราะว่า': 1.878860471124263e-05,
#              'ออสซี่': 7.5154418844970525e-06,
#              'หลังจากที่': 3.757720942248526e-05,
#              'หวาดวิตก': 3.7577209422485262e-06,
#              'หวน': 1.8788604711242631e-06,
#              '09': 0.0001277625120364499,
#              'น.': 0.001213743864346274,
#              'ท่าอากาศยานทหาร กองบิน 6': 1.8788604711242631e-06,
#              'ระดมสมอง': 9.394302355621316e-07,
#              'มหาวิทยาลัย': 7.327555837384626e-05,
#              'OIE': 7.5154418844970525e-06,
#              'WHO': 2.8182907066863946e-06,
#              'เดินทาง': 0.0009121867587308297,
#              'ข่าวสาร': 2.912233730242608e-05,
#              'กันและกัน': 1.2212593062307711e-05,
#              'ยิ่ง': 0.0002320392681838465,
#              'อุจจาระ': 8.454872120059185e-06,
#              'ข้อ': 0.00105779844524296,
#              'ซักถาม': 3.1940628009112476e-05,
#              'เกี่ยว': 0.0004340167688297048,
#              'พ.ต.ท.ทักษิณ': 0.0005730524436929002,
#              'ตอบ': 0.0002470701519528406,
#              'ตอน': 0.0005063528969679889,
#              'เอา': 0.0005335963737992907,
#              'มก.': 1.8788604711242631e-06,
#              'รศ.ดร.วิโรจ อิ่มพิทักษ์': 9.394302355621316e-07,
#              'อธิการบดี': 3.757720942248526e-05,
#              'รศ.น.สพ.ดร.ธานีรัตน์ สานติวัตร': 9.394302355621316e-07,
#              'ผศ.น.สพ.ธีระพล ศิรินฤมิตร': 9.394302355621316e-07,
#              'ผศ.น.สพ.ดร.ทวีศักดิ์ ส่งเสริม': 9.394302355621316e-07,
#              'ผศ.น.สพ.ธีระพล': 1.8788604711242631e-06,
#              'ทีม': 0.000507292327203551,
#              'สวนสัตว์เปิดเขาเขียว': 9.394302355621316e-07,
#              'ถอด': 4.791094201366871e-05,
#              'รหัส': 2.7243476831301816e-05,
#              'พันธุกรรม': 1.2212593062307711e-05,
#              'เหมือน': 0.0004490476525986989,
#              'ไล่เลี่ย': 1.3152023297869842e-05,
#              'สูง': 0.0009159444796730783,
#              '106': 9.394302355621316e-06,
#              'องศา': 6.106296531153855e-05,
#              'อาเจียน': 5.636581413372789e-06,
#              'คล้าย': 7.1396697902722e-05,
#              'ชันสูตร': 2.6304046595739685e-05,
#              'มหาวิทยาลัยเกษตรศาสตร์บางเขน': 9.394302355621316e-07,
#              'เก็บ': 0.0003729538035181662,
#              'คัดหลั่ง': 6.576011648934921e-06,
#              'จมูก': 1.4091453533431974e-05,
#              'เพาะ': 4.791094201366871e-05,
#              'เทคนิค': 2.912233730242608e-05,
#              'พีซีอาร์': 3.7577209422485262e-06,
#              '35': 0.000107095046854083,
#              'ผศ.น.สพ.ดร.ธานีรัตน์': 1.8788604711242631e-06,
#              'ไม่ว่า': 0.00018224946569905353,
#              'ควาย': 5.636581413372789e-06,
#              'วัว': 1.690974424011837e-05,
#              'สุนัข': 7.703327931609478e-05,
#              'ลักษณะ': 0.00022358439606378732,
#              'นิสัย': 2.1606895417929025e-05,
#              'ชอบ': 0.00022358439606378732,
#              'เลีย': 1.8788604711242631e-06,
#              'ดูด': 1.690974424011837e-05,
#              'สูด': 2.8182907066863946e-06,
#              'ดม': 1.2212593062307711e-05,
#              'chicken': 9.394302355621316e-07,
#              'tiger': 9.394302355621316e-07,
#              'leopard': 9.394302355621316e-07,
#              'cat': 9.394302355621316e-07,
#              'องค์การเฝ้าระวังโรคระบาดในสัตว์': 9.394302355621316e-07,
#              'คืบหน้า': 0.00020385636111698254,
#              'พยายาม': 0.0003955001291716574,
#              'ขัง': 0.0001634608609878109,
#              'ก็ได้': 1.5030883768994105e-05,
#              'น้ำลาย': 8.454872120059185e-06,
#              'เล่น': 0.0002977993846731957,
#              'ล้าง': 2.6304046595739685e-05,
#              'หมั่น': 7.5154418844970525e-06,
#              'สุขอนามัย': 6.576011648934921e-06,
#              'บริเวณ': 0.0008840038516639658,
#              'แม้ว่า': 9.394302355621315e-05,
#              'กรมปศุสัตว์': 4.039550012917166e-05,
#              'น.สพ.คงศักดิ์ เที่ยงธรรม': 9.394302355621316e-07,
#              'ผอ.': 0.0001493694074543789,
#              'โรงพยาบาลสัตว์': 1.8788604711242631e-06,
#              'อยาก': 0.0007233612813828413,
#              'ปฏิบัติ': 0.0005251415016792316,
#              'ซัก': 1.1273162826745578e-05,
#              'ขาว': 8.454872120059185e-05,
#              'ไลโซล': 9.394302355621316e-07,
#              'ราด': 9.394302355621316e-06,
#              'สวม': 0.00015312712839662745,
#              '00': 0.0006970572347871016,
#              'อาคารจามจุรี 4': 9.394302355621316e-07,
#              'จุฬาลงกรณ์มหาวิทยาลัย': 2.0667465182366894e-05,
#              'ศ.น.สพ.ดร.ณรงค์ศักดิ์ ชัยบุตร': 9.394302355621316e-07,
#              'คณะสัตวแพทยศาสตร์ จุฬาฯ': 1.8788604711242631e-06,
#              'ศ.น.พ.ยง ภู่วรรณ': 9.394302355621316e-07,
#              'หน่วย': 0.0003964395594072195,
#              'ตับ': 4.697151177810658e-06,
#              'คณะแพทยศาสตร์ จุฬาฯ': 9.394302355621316e-07,
#              'รศ.น.สพ.ดร.คณิศักดิ์ อรวีระกุล': 9.394302355621316e-07,
#              'ไวรัสวิทยา': 3.7577209422485262e-06,
#              'ภาควิชาพยาธิวิทยา': 9.394302355621316e-07,
#              'เปิด': 0.0007008149557293502,
#              'สำเร็จ': 0.00014373282604100612,
#              'จุฬา': 3.7577209422485262e-06,
#              'ประสบ': 0.0002508278728950891,
#              'เมืองไทย': 4.227436060029592e-05,
#              'ประโยชน์': 0.0003419526057446159,
#              'พื้นฐาน': 6.012353507597642e-05,
#              'พัฒนาการ': 1.4091453533431974e-05,
#              'แม่นยำ': 3.7577209422485262e-06,
#              'วิวัฒนาการ': 4.697151177810658e-06,
#              'อัน': 0.00018037060522792925,
#              'อนาคต': 0.00011930763991639071,
#              'วัคซีน': 6.106296531153855e-05,
#              'สำนัก': 9.957960496958595e-05,
#              'เอพี': 3.7577209422485262e-06,
#              'เอเอฟพี': 3.7577209422485262e-06,
#              'รอยเตอร์': 2.8182907066863946e-06,
#              'ประโคมข่าว': 9.394302355621316e-07,
#              'โผล่': 3.2880058244674604e-05,
#              'พ้อง': 7.5154418844970525e-06,
#              'แลกเปลี่ยน': 3.4758918715798866e-05,
#              'ยับยั้ง': 2.5364616360177554e-05,
#              'ปราบปราม': 6.576011648934921e-05,
#              'คร่า': 7.5154418844970525e-06,
#              'จังหวัดนครพนม': 3.7577209422485262e-06,
#              'กระทรวงเกษตรจีน': 9.394302355621316e-07,
#              'เมืองอันหนิง': 9.394302355621316e-07,
#              'มณฑลยูนนาน': 9.394302355621316e-07,
#              'ภาคตะวันตกเฉียงใต้': 9.394302355621316e-07,
#              'เมืองฮวยหยิน': 9.394302355621316e-07,
#              'มณฑลชานสี': 9.394302355621316e-07,
#              'ตะวันตกเฉียงเหนือ': 9.394302355621316e-07,
#              'จีน': 0.00013809624462763335,
#              'ห่าน': 1.4091453533431974e-05,
#              'เป็ด': 3.5698348951361e-05,
#              'แคนาดา': 1.1273162826745578e-05,
#              'มณฑลบริติช': 9.394302355621316e-07,
#              'โคลัมเบีย': 1.1273162826745578e-05,
#              'ญี่ปุ่น': 0.00011836820968082858,
#              'ระงับ': 7.045726766715987e-05,
#              'มณฑลบริติช โคลัมเบีย': 9.394302355621316e-07,
#              'กระนั้น': 1.8788604711242631e-06,
#              'เอเชีย': 6.388125601822495e-05,
#              'วี่แวว': 1.8788604711242631e-06,
#              'สงบ': 0.00022076610535710093,
#              'ออสเตรเลีย': 5.918410484041429e-05,
#              'องค์กรวิจัยวิทยาศาสตร์และอุตสาหกรรมแห่งเครือจักรภพ': 9.394302355621316e-07,
#              'CSIRO': 2.8182907066863946e-06,
#              'รีเลนซา': 3.7577209422485262e-06,
#              'Relenza': 9.394302355621316e-07,
#              'โปรตีน': 5.636581413372789e-06,
#              'เซลล์': 1.0333732591183447e-05,
#              'แบ่ง': 0.00018037060522792925,
#              'เจนนี แมคคิมม์เบรชกิน': 9.394302355621316e-07,
#              'ทดสอบ': 4.8850372249230845e-05,
#              'บรรเทา': 4.978980248479297e-05,
#              'ราคา': 0.0006153268042931962,
#              'หุ้น': 0.0001672185819300594,
#              'บริษัทไบโอต้าโฮลดิ้ง': 9.394302355621316e-07,
#              'พุ่ง': 9.300359332065102e-05,
#              '51': 3.2880058244674604e-05,
#              'บริษัท': 0.0002611616054862726,
#              'สนับสนุน': 0.00026304046595739683,
#              '2542': 2.1606895417929025e-05,
#              '16832': 9.394302355621316e-07,
#              'ลาม': 2.2546325653491157e-05,
#              'ลำดับ': 7.985157002278118e-05,
#              'หัน': 9.394302355621315e-05,
#              '19': 0.00019728034946804763,
#              'สัมมนา': 4.227436060029592e-05,
#              'แนวทาง': 0.00023485755889053288,
#              'โรงแรมรามาการ์เด้นส์': 3.7577209422485262e-06,
#              'นายเนวิน ชิดชอบ': 3.4758918715798866e-05,
#              'รมช.': 8.079100025834332e-05,
#              ...})

# %%
def getLnValue(x):
    if x >0.0:
        return math.log(x)
    else:
        return math.log(unk_value)

# %%
#problability of 'นายก'
print(getLnValue(model[u'นายก']))
#for example, problability of 'นายกรัฐมนตรี' which is an unknown word is equal to
print(getLnValue(model[u'นายกรัฐมนตรี']))
#problability of 'นายก' 'ได้' 'ให้' 'สัมภาษณ์' 'กับ' 'สื่อ'
prob = getLnValue(model[u'นายก'])+getLnValue(model[u'ได้'])+ getLnValue(model[u'ให้'])+getLnValue(model[u'สัมภาษณ์'])+getLnValue(model[u'กับ'])+getLnValue(model[u'สื่อ'])+getLnValue(model['</s>'])
print ('Problability of a sentence', math.exp(prob))
# Out:
# -6.551526663995246
# -10.175040243058024
# Problability of a sentence 5.617210748667918e-18
