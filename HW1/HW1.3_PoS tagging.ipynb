# %% [markdown]
# # HW 3 - Neural POS Tagger
#
# In this exercise, you are going to build a set of deep learning models on part-of-speech (POS) tagging using Tensorflow 2. Tensorflow is a deep learning framwork developed by Google to provide an easier way to use standard layers and networks.
#
# To complete this exercise, you will need to build deep learning models for POS tagging in Thai using NECTEC's ORCHID corpus. You will build one model for each of the following type:
#
# - Neural POS Tagging with Word Embedding using Fixed / non-Fixed Pretrained weights
# - Neural POS Tagging with Viterbi / Marginal CRF
#
# Pretrained word embeddding are already given for you to use (albeit, a very bad one).
#
# We also provide the code for data cleaning, preprocessing and some starter code for tensorflow 2 in this notebook but feel free to modify those parts to suit your needs. Feel free to use additional libraries (e.g. scikit-learn) as long as you have a model for each type mentioned above.
#
# ### Don't forget to change hardware accelrator to GPU in runtime on Google Colab ###

# %% [markdown]
# ## 1. Setup and Preprocessing

# %% [markdown]
# We use POS data from [ORCHID corpus](https://www.nectec.or.th/corpus/index.php?league=pm), which is a POS corpus for Thai language.
# A method used to read the corpus into a list of sentences with (word, POS) pairs have been implemented already. The example usage has shown below.
# We also create a word vector for unknown word by random.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# %tensorflow_version 2.x

# %%
# import shutil
# shutil.copy("/content/drive/MyDrive/FRA 501 IntroNLP&DL/Dataset/resources.zip", "/content/resources.zip")
# !unzip resources.zip

####Every Platform####
# import urllib.request
# url = 'https://drive.google.com/drive/folders/1fdKB1j1h_iD68PE8Wg5Al_J0M5IRrMNS?usp=share_link'
# file_name = 'resources.zip'
# urllib.request.urlretrieve(url, file_name)
######################

# %%
# import rarfile

# # specify the name of the WinRAR ZIP file and the directory where you want to extract its contents
# zip_file = 'resources.zip'
# extract_dir = 'D:\FRA501-NLP\HW1'

# # open the WinRAR ZIP file for reading
# with rarfile.RarFile(zip_file, 'r') as zip_obj:
#     # extract all contents to the specified directory
#     zip_obj.extractall(extract_dir)

# %%
# %pip install python-crfsuite
# %pip install tensorflow-addons
# %pip install tf2crf
# Out:
# Requirement already satisfied: python-crfsuite in c:\users\kla\anaconda3\lib\site-packages (0.9.9)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow-addons in c:\users\kla\anaconda3\lib\site-packages (0.19.0)
# Requirement already satisfied: packaging in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-addons) (2.13.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kla\anaconda3\lib\site-packages (from packaging->tensorflow-addons) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tf2crf in c:\users\kla\anaconda3\lib\site-packages (0.1.33)
# Requirement already satisfied: tensorflow-addons>=0.8.2 in c:\users\kla\anaconda3\lib\site-packages (from tf2crf) (0.19.0)
# Requirement already satisfied: tensorflow>=2.1.0 in c:\users\kla\anaconda3\lib\site-packages (from tf2crf) (2.11.0)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow>=2.1.0->tf2crf) (2.11.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (23.1.21)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2.11.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (61.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (15.0.6.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (3.19.1)
# Requirement already satisfied: packaging in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (21.3)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (4.1.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.30.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2.11.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.42.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.12.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.21.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\kla\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kla\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (3.3.4)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\kla\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\kla\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.33.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\kla\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\kla\anaconda3\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.6.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\kla\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kla\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\kla\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\kla\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\kla\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\kla\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kla\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kla\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\kla\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (1.26.9)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\kla\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (3.2.2)
# Requirement already satisfied: typeguard>=2.7 in c:\users\kla\anaconda3\lib\site-packages (from tensorflow-addons>=0.8.2->tf2crf) (2.13.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\kla\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.11.0->tensorflow>=2.1.0->tf2crf) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %tensorflow_version 2.x

# %%
from data.orchid_corpus import get_sentences
import numpy as np
import numpy.random
import tensorflow as tf
np.random.seed(42)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# d:\FRA501-NLP\HW1\HW1.3_PoS tagging.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/FRA501-NLP/HW1/HW1.3_PoS%20tagging.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> from data.orchid_corpus import get_sentences
#       <a href='vscode-notebook-cell:/d%3A/FRA501-NLP/HW1/HW1.3_PoS%20tagging.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/d%3A/FRA501-NLP/HW1/HW1.3_PoS%20tagging.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> import numpy.random
#
# ModuleNotFoundError: No module named 'data'

# %%
yunk_emb =np.random.randn(32)
train_data = get_sentences('train')
test_data = get_sentences('test')
print(train_data[0])

# %%
yunk_emb

# %% [markdown]
# Next, we load pretrained weight embedding using pickle. The pretrained weight is a dictionary which map a word to its embedding.

# %%
import pickle
fp = open('basic_ff_embedding.pt', 'rb')
embeddings = pickle.load(fp)
fp.close()

# %%
embeddings

# %% [markdown]
# The given code below generates an indexed dataset(each word is represented by a number) for training and testing data. The index 0 is reserved for padding to help with variable length sequence. (Additionally, You can read more about padding here [https://machinelearningmastery.com/data-preparation-variable-length-input-sequences-sequence-prediction/])

# %% [markdown]
# ## 2. Prepare Data

# %%
word_to_idx ={}
idx_to_word ={}
label_to_idx = {}
for sentence in train_data:
    for word,pos in sentence:
        if word not in word_to_idx:
            word_to_idx[word] = len(word_to_idx)+1
            idx_to_word[word_to_idx[word]] = word
        if pos not in label_to_idx:
            label_to_idx[pos] = len(label_to_idx)+1
word_to_idx['UNK'] = len(word_to_idx)

n_classes = len(label_to_idx.keys())+1

# %%
n_classes

# %% [markdown]
# This section is tweaked a little from the demo, word2features will return word index instead of features, and sent2labels will return a sequence of word indices in the sentence.

# %%
def word2features(sent, i, emb):
    word = sent[i][0]
    if word in word_to_idx :
        return word_to_idx[word]
    else :
        return word_to_idx['UNK']

def sent2features(sent, emb_dict):
    return np.asarray([word2features(sent, i, emb_dict) for i in range(len(sent))])

def sent2labels(sent):
    return numpy.asarray([label_to_idx[label] for (word, label) in sent],dtype='int32')

def sent2tokens(sent):
    return [word for (word, label) in sent]

# %%
sent2features(train_data[100], embeddings)

# %% [markdown]
# Next we create train and test dataset, then we use tensorflow 2 to post-pad the sequence to max sequence with 0. Our labels are changed to a one-hot vector.

# %%
# %%time
x_train = np.asarray([sent2features(sent, embeddings) for sent in train_data])
y_train = [sent2labels(sent) for sent in train_data]
x_test = [sent2features(sent, embeddings) for sent in test_data]
y_test = [sent2labels(sent) for sent in test_data]

# %%
x_train=tf.keras.preprocessing.sequence.pad_sequences(x_train, maxlen=None, dtype='int32', padding='post', truncating='pre', value=0.)
y_train=tf.keras.preprocessing.sequence.pad_sequences(y_train, maxlen=None, dtype='int32', padding='post', truncating='pre', value=0.)
x_test=tf.keras.preprocessing.sequence.pad_sequences(x_test, maxlen=102, dtype='int32', padding='post', truncating='pre', value=0.)
y_temp =[]
for i in range(len(y_train)):
    y_temp.append(np.eye(n_classes)[y_train[i]][np.newaxis,:])
y_train = np.asarray(y_temp).reshape(-1,102,n_classes)
del(y_temp)

# %%
print(x_train[100],x_train.shape)
print(y_train[100][3],y_train.shape)

# %% [markdown]
# ## 3. Evaluate

# %% [markdown]
# Our output from tf keras is a distribution of problabilities on all possible label. outputToLabel will return an indices of maximum problability from output sequence.
#
# evaluation_report is the same as in the demo

# %%
def outputToLabel(yt,seq_len):
    out = []
    for i in range(0,len(yt)):
        if(i==seq_len):
            break
        out.append(np.argmax(yt[i]))
    return out

# %%
import pandas as pd
from IPython.display import display

def evaluation_report(y_true, y_pred):
    # retrieve all tags in y_true
    tag_set = set()
    for sent in y_true:
        for tag in sent:
            tag_set.add(tag)
    for sent in y_pred:
        for tag in sent:
            tag_set.add(tag)
    tag_list = sorted(list(tag_set))
    
    # count correct points
    tag_info = dict()
    for tag in tag_list:
        tag_info[tag] = {'correct_tagged': 0, 'y_true': 0, 'y_pred': 0}

    all_correct = 0
    all_count = sum([len(sent) for sent in y_true])
    for sent_true, sent_pred in zip(y_true, y_pred):
        for tag_true, tag_pred in zip(sent_true, sent_pred):
            if tag_true == tag_pred:
                tag_info[tag_true]['correct_tagged'] += 1
                all_correct += 1
            tag_info[tag_true]['y_true'] += 1
            tag_info[tag_pred]['y_pred'] += 1
    accuracy = (all_correct / all_count) * 100
            
    # summarize and make evaluation result
    eval_list = list()
    for tag in tag_list:
        eval_result = dict()
        eval_result['tag'] = tag
        eval_result['correct_count'] = tag_info[tag]['correct_tagged']
        precision = (tag_info[tag]['correct_tagged']/tag_info[tag]['y_pred'])*100 if tag_info[tag]['y_pred'] else '-'
        recall = (tag_info[tag]['correct_tagged']/tag_info[tag]['y_true'])*100 if (tag_info[tag]['y_true'] > 0) else 0
        eval_result['precision'] = precision
        eval_result['recall'] = recall
        eval_result['f_score'] = (2*precision*recall)/(precision+recall) if (type(precision) is float and recall > 0) else '-'
        
        eval_list.append(eval_result)

    eval_list.append({'tag': 'accuracy=%.2f' % accuracy, 'correct_count': '', 'precision': '', 'recall': '', 'f_score': ''})
    
    df = pd.DataFrame.from_dict(eval_list)
    df = df[['tag', 'precision', 'recall', 'f_score', 'correct_count']]
    display(df)

# %% [markdown]
# ## 4. Train a model

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Embedding, Reshape, Activation, Input, Dense,GRU,Reshape,TimeDistributed,Bidirectional,Dropout,Masking
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# The model is this section is separated to two groups
#
# - Neural POS Tagger (4.1)
# - Neural CRF POS Tagger (4.2)

# %% [markdown]
# ## 4.1 Neural POS Tagger  (Example)

# %% [markdown]
# We create a simple Neural POS Tagger as an example for you. This model dosen't use any pretrained word embbeding so it need to use Embedding layer to train the word embedding from scratch.
#
# Instead of using tensorflow.keras.models.Sequential, we use tensorflow.keras.models.Model. The latter is better as it can have multiple input/output, of which Sequential model could not. Due to this reason, the Model class is widely used for building a complex deep learning model.

# %%
inputs = Input(shape=(102,), dtype='int32')
output = (Embedding(len(word_to_idx),32,input_length=102,mask_zero=True))(inputs)
output = Bidirectional(GRU(32, return_sequences=True))(output)
output = Dropout(0.2)(output)
output = TimeDistributed(Dense(n_classes,activation='softmax'))(output)
model = Model(inputs, output)
model.compile(optimizer=Adam(lr=0.001),  loss='categorical_crossentropy', metrics=['categorical_accuracy'])

model.summary()
model.fit(x_train,y=y_train, batch_size=64,epochs=10,verbose=1)

# %%
# %%time
model.fit(x_train,y_train,batch_size=64,epochs=10,verbose=1)

# %%
# %%time
#model.save_weights('/data/my_pos_no_crf.h5')
#model.load_weights('/data/my_pos_no_crf.h5')
y_pred=model.predict(x_test)
ypred = [outputToLabel(y_pred[i],len(y_test[i])) for i in range(len(y_pred))]
evaluation_report(y_test, ypred)

# %% [markdown]
# ## 4.2 CRF Viterbi

# %% [markdown]
# Your next task is to incorporate Conditional random fields (CRF) to your model.
#
# To use the CRF layer, you need to use an extension repository for tensorflow library, call tf2crf. If you want to see the detailed implementation, you should read the official tensorflow extention of CRF (https://www.tensorflow.org/addons/api_docs/python/tfa/text).
#
# tf2crf link :  https://github.com/xuxingya/tf2crf
#
# For inference, you should look at crf.py at the method call and view the input/output argmunets.
# Link : https://github.com/xuxingya/tf2crf/blob/master/tf2crf/crf.py

# %% [markdown]
# ### 4.2.1 CRF without pretrained weight
# ### #TODO 1
# Incoperate CRF layer to your model in 4.1. CRF is quite complex compare to previous example model, so you should train it with more epoch, so it can converge.
#
# To finish this excercise you must train the model and show the evaluation report with this model as shown in the example.
#
# Do not forget to save this model weight.

# %%
# INSERT YOUR CODE HERE

# %% [markdown]
# ### 4.2.2 CRF with pretrained weight
#
# ### #TODO 2
#
# We would like you create a neural CRF POS tagger model  with the pretrained word embedding as an input and the word embedding is trainable (not fixed). To finish this excercise you must train the model and show the evaluation report with this model as shown in the example.
#
# Please note that the given pretrained word embedding only have weights for the vocabuary in BEST corpus.
#
# You can read more information about using predtained weight in embedding layer on Keras from the following link:
#
# https://keras.io/examples/nlp/pretrained_word_embeddings/
#
# Optionally, you can use your own pretrained word embedding.
#
# #### Hint: You can get the embedding from get_embeddings function from embeddings/emb_reader.py .
#
# (You may want to read about Tensorflow Masking layer and Trainable parameter)

# %%
# INSERT YOUR CODE HERE

# %% [markdown]
# ### #TODO 3
# Compare the result between all neural tagger models in 4.1 and 4.2.x and provide a convincing reason and example for the result of these models (which model perform better, why?)
#
# (If you use your own weight please state so in the answer)

# %% [markdown]
# <b>Write your answer here :</b>
